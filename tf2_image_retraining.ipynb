# %% [markdown]
# # Transfer Learning and Fine-tuning Image Classifier for UI Data Classification

# %% [markdown]
# Image classification models consist of millions of parameters. Training them from scratch requires a large amount of labeled training data and substantial computing power. Transfer learning is a technique that reduces this resource consumption by reusing parts of a model already trained on a related task in a new model.
#
# This Colab notebook aims to create a model for classifying UI data. It performs image feature extraction using a pre-trained TF2 SavedModel from TensorFlow Hub (trained on a larger and more general ImageNet dataset), and builds a Keras model to classify the UI data based on this. Additionally, it includes the process of fine-tuning the feature extractor with the newly added classifier.
#
# Finally, this model is converted for TFJS, making it easily usable on the web.
#
# This notebook was created by reworking [Google's official tutorial document](https://www.tensorflow.org/hub/tutorials/tf2_image_retraining?hl=ko).

# %% [markdown]
# ## 1. Setup
# ### 1-1. Importing Libraries

# %%
import itertools
import os

import matplotlib.pylab as plt
import numpy as np

import tensorflow as tf
import tensorflow_hub as hub

print("TF version:", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TF version: 2.14.0
# Hub version: 0.16.0.dev
# GPU is available

# %% [markdown]
# ### 1-2. Selecting a TF2 SavedModel Module
#
# In this notebook, we use the [https://tfhub.dev/google/imagenet/mobilenet_v3_small_100_224/feature_vector/5](https://tfhub.dev/google/imagenet/mobilenet_v3_small_100_224/feature_vector/5) model by default. This URL can be used in the code to identify the SavedModel and display its documentation in the browser.
#
# You can choose from various models. You can find more TF2 models that generate image feature vectors [here](https://tfhub.dev/s?module-type=image-feature-vector&tf-version=tf2).
#
# > **Note**: Although TensorFlow Hub has moved to [Kaggle Models](https://www.kaggle.com/models), you can still use the models in the same way as before.

# %%
#@title

model_name = "mobilenet_v3_small_100_224" # @param ['efficientnetv2-s', 'efficientnetv2-m', 'efficientnetv2-l', 'efficientnetv2-s-21k', 'efficientnetv2-m-21k', 'efficientnetv2-l-21k', 'efficientnetv2-xl-21k', 'efficientnetv2-b0-21k', 'efficientnetv2-b1-21k', 'efficientnetv2-b2-21k', 'efficientnetv2-b3-21k', 'efficientnetv2-s-21k-ft1k', 'efficientnetv2-m-21k-ft1k', 'efficientnetv2-l-21k-ft1k', 'efficientnetv2-xl-21k-ft1k', 'efficientnetv2-b0-21k-ft1k', 'efficientnetv2-b1-21k-ft1k', 'efficientnetv2-b2-21k-ft1k', 'efficientnetv2-b3-21k-ft1k', 'efficientnetv2-b0', 'efficientnetv2-b1', 'efficientnetv2-b2', 'efficientnetv2-b3', 'efficientnet_b0', 'efficientnet_b1', 'efficientnet_b2', 'efficientnet_b3', 'efficientnet_b4', 'efficientnet_b5', 'efficientnet_b6', 'efficientnet_b7', 'bit_s-r50x1', 'inception_v3', 'inception_resnet_v2', 'resnet_v1_50', 'resnet_v1_101', 'resnet_v1_152', 'resnet_v2_50', 'resnet_v2_101', 'resnet_v2_152', 'nasnet_large', 'nasnet_mobile', 'pnasnet_large', 'mobilenet_v2_100_224', 'mobilenet_v2_130_224', 'mobilenet_v2_140_224', 'mobilenet_v3_small_100_224', 'mobilenet_v3_small_075_224', 'mobilenet_v3_large_100_224', 'mobilenet_v3_large_075_224']

model_handle_map = {
  "efficientnetv2-s": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_s/feature_vector/2",
  "efficientnetv2-m": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_m/feature_vector/2",
  "efficientnetv2-l": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_l/feature_vector/2",
  "efficientnetv2-s-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_s/feature_vector/2",
  "efficientnetv2-m-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_m/feature_vector/2",
  "efficientnetv2-l-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_l/feature_vector/2",
  "efficientnetv2-xl-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_xl/feature_vector/2",
  "efficientnetv2-b0-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b0/feature_vector/2",
  "efficientnetv2-b1-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b1/feature_vector/2",
  "efficientnetv2-b2-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b2/feature_vector/2",
  "efficientnetv2-b3-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b3/feature_vector/2",
  "efficientnetv2-s-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_s/feature_vector/2",
  "efficientnetv2-m-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_m/feature_vector/2",
  "efficientnetv2-l-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_l/feature_vector/2",
  "efficientnetv2-xl-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_xl/feature_vector/2",
  "efficientnetv2-b0-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_b0/feature_vector/2",
  "efficientnetv2-b1-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_b1/feature_vector/2",
  "efficientnetv2-b2-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_b2/feature_vector/2",
  "efficientnetv2-b3-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_b3/feature_vector/2",
  "efficientnetv2-b0": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b0/feature_vector/2",
  "efficientnetv2-b1": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b1/feature_vector/2",
  "efficientnetv2-b2": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b2/feature_vector/2",
  "efficientnetv2-b3": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b3/feature_vector/2",
  "efficientnet_b0": "https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1",
  "efficientnet_b1": "https://tfhub.dev/tensorflow/efficientnet/b1/feature-vector/1",
  "efficientnet_b2": "https://tfhub.dev/tensorflow/efficientnet/b2/feature-vector/1",
  "efficientnet_b3": "https://tfhub.dev/tensorflow/efficientnet/b3/feature-vector/1",
  "efficientnet_b4": "https://tfhub.dev/tensorflow/efficientnet/b4/feature-vector/1",
  "efficientnet_b5": "https://tfhub.dev/tensorflow/efficientnet/b5/feature-vector/1",
  "efficientnet_b6": "https://tfhub.dev/tensorflow/efficientnet/b6/feature-vector/1",
  "efficientnet_b7": "https://tfhub.dev/tensorflow/efficientnet/b7/feature-vector/1",
  "bit_s-r50x1": "https://tfhub.dev/google/bit/s-r50x1/1",
  "inception_v3": "https://tfhub.dev/google/imagenet/inception_v3/feature-vector/4",
  "inception_resnet_v2": "https://tfhub.dev/google/imagenet/inception_resnet_v2/feature-vector/4",
  "resnet_v1_50": "https://tfhub.dev/google/imagenet/resnet_v1_50/feature-vector/4",
  "resnet_v1_101": "https://tfhub.dev/google/imagenet/resnet_v1_101/feature-vector/4",
  "resnet_v1_152": "https://tfhub.dev/google/imagenet/resnet_v1_152/feature-vector/4",
  "resnet_v2_50": "https://tfhub.dev/google/imagenet/resnet_v2_50/feature-vector/4",
  "resnet_v2_101": "https://tfhub.dev/google/imagenet/resnet_v2_101/feature-vector/4",
  "resnet_v2_152": "https://tfhub.dev/google/imagenet/resnet_v2_152/feature-vector/4",
  "nasnet_large": "https://tfhub.dev/google/imagenet/nasnet_large/feature_vector/4",
  "nasnet_mobile": "https://tfhub.dev/google/imagenet/nasnet_mobile/feature_vector/4",
  "pnasnet_large": "https://tfhub.dev/google/imagenet/pnasnet_large/feature_vector/4",
  "mobilenet_v2_100_224": "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/4",
  "mobilenet_v2_130_224": "https://tfhub.dev/google/imagenet/mobilenet_v2_130_224/feature_vector/4",
  "mobilenet_v2_140_224": "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4",
  "mobilenet_v3_small_100_224": "https://tfhub.dev/google/imagenet/mobilenet_v3_small_100_224/feature_vector/5",
  "mobilenet_v3_small_075_224": "https://tfhub.dev/google/imagenet/mobilenet_v3_small_075_224/feature_vector/5",
  "mobilenet_v3_large_100_224": "https://tfhub.dev/google/imagenet/mobilenet_v3_large_100_224/feature_vector/5",
  "mobilenet_v3_large_075_224": "https://tfhub.dev/google/imagenet/mobilenet_v3_large_075_224/feature_vector/5",
}

model_image_size_map = {
  "efficientnetv2-s": 384,
  "efficientnetv2-m": 480,
  "efficientnetv2-l": 480,
  "efficientnetv2-b0": 224,
  "efficientnetv2-b1": 240,
  "efficientnetv2-b2": 260,
  "efficientnetv2-b3": 300,
  "efficientnetv2-s-21k": 384,
  "efficientnetv2-m-21k": 480,
  "efficientnetv2-l-21k": 480,
  "efficientnetv2-xl-21k": 512,
  "efficientnetv2-b0-21k": 224,
  "efficientnetv2-b1-21k": 240,
  "efficientnetv2-b2-21k": 260,
  "efficientnetv2-b3-21k": 300,
  "efficientnetv2-s-21k-ft1k": 384,
  "efficientnetv2-m-21k-ft1k": 480,
  "efficientnetv2-l-21k-ft1k": 480,
  "efficientnetv2-xl-21k-ft1k": 512,
  "efficientnetv2-b0-21k-ft1k": 224,
  "efficientnetv2-b1-21k-ft1k": 240,
  "efficientnetv2-b2-21k-ft1k": 260,
  "efficientnetv2-b3-21k-ft1k": 300, 
  "efficientnet_b0": 224,
  "efficientnet_b1": 240,
  "efficientnet_b2": 260,
  "efficientnet_b3": 300,
  "efficientnet_b4": 380,
  "efficientnet_b5": 456,
  "efficientnet_b6": 528,
  "efficientnet_b7": 600,
  "inception_v3": 299,
  "inception_resnet_v2": 299,
  "nasnet_large": 331,
  "pnasnet_large": 331,
}

model_handle = model_handle_map.get(model_name)
pixels = model_image_size_map.get(model_name, 224)

print(f"Selected model: {model_name} : {model_handle}")

IMAGE_SIZE = (pixels, pixels)
print(f"Input size {IMAGE_SIZE}")

BATCH_SIZE = 16#@param {type:"integer"}
# Out:
# Selected model: mobilenet_v3_small_100_224 : https://tfhub.dev/google/imagenet/mobilenet_v3_small_100_224/feature_vector/5
# Input size (224, 224)

# %% [markdown]
# ## 2. Preparing the UI Dataset
#
# The input is adjusted to the appropriate size according to the selected module. Dataset augmentation (i.e., random distortion of the image each time it is read) can particularly improve training when fine-tuning. To preparing the dataset, you need to aware the following:
#
# 1. Collect images of UI components from actual projects or screen captures. It is advisable to secure at least 50 images for each UI component, and the recommended quantity is more than 100 images.
# 2. If it is difficult to secure such a quantity of images, it is recommended to generate images using [figma-dummy-gen](https://github.com/dusskapark/figma-dummy-gen) and use them in conjunction with the images actually captured.
# 3. Put the prepared dataset in the `dataset` folder.

# %%
# Define the root path and the origin path
root_path = os.path.expanduser('./dataset/')
origin_path = root_path + 'TF_Image_classification/' # folder that contains the dummy images
screenshot_path = root_path + 'screenshot/' # folder that contains the real images that captured from the UI or Figma projects 
ui_path = root_path + 'ui/' # final UI dataset folder 

# Print the root path and the origin path
print('Origin path:', origin_path)
print('Screenshot path:', screenshot_path)
print('UI path:', ui_path)
# Out:
# Origin path: ./dataset/TF_Image_classification/
# Screenshot path: ./dataset/screenshot/
# UI path: ./dataset/ui/

# %% [markdown]
# ### 2-1. Checking the Original Dataset Structure
#
# The dataset is stored in the `origin_path`. The folder structure is as follows:
#
# ```
# TF_Image_classification
# |__ Accordion
#     |______ 100080576_f52e8ee070_n.jpg
#     |______ 14167534527_781ceb1b7a_n.jpg
#     |______ ...
# |__ App Bar
#     |______ 10043234166_e6dd915111_n.jpg
#     |______ 1426682852_e62169221f_m.jpg
#     |______ ...
# ```
#
# You can use the following code to identify the names of each folder and the number of files in each folder.

# %%
# Function to get the number of files in a directory
def get_num_files(path):
    return len([entry for entry in os.scandir(path) if entry.is_file()])

# Function to print the directory tree
def draw_folder_tree(path, level=0):
    expanded_path = os.path.expanduser(path)
    folders_files_count = {}

    for entry in os.scandir(expanded_path):
        if entry.is_dir():
            num_files = get_num_files(entry.path)
            folders_files_count[entry.name] = num_files

    sorted_folders_files_count = sorted(folders_files_count.items(), key=lambda item: item[0])

    for folder_name, files_count in sorted_folders_files_count:
        print(f"{'    '*level}|- {folder_name}/ ({files_count} files)")
        draw_folder_tree(os.path.join(path, folder_name), level+1)
        
# Draw the folder tree of the new directory
print('Train structure:')
draw_folder_tree(origin_path)
# Out:
# Train structure:
# |- Accordion/ (320 files)
# |- App Bar/ (240 files)
# |- Avatar/ (30 files)
# |- Badge/ (368 files)
# |- Banner/ (1536 files)
# |- Bottom navigation/ (136 files)
# |- Bottom sheet/ (512 files)
# |- Buttons/ (354 files)
# |- Card/ (1169 files)
# |- Dropdown/ (416 files)
# |- Enter amount/ (1152 files)
# |- Filter and sort/ (432 files)
# |- Icon/ (3419 files)
# |- Link/ (216 files)
# |- List items/ (5232 files)
# |- Modal loader/ (192 files)
# |- Nudge/ (2048 files)
# |- OTP/ (257 files)
# |- Onboarding Stories/ (216 files)
# |- Progress Tracker/ (592 files)
# |- Quick Actions/ (132 files)
# |- Quick Select/ (344 files)
# |- Section Header/ (288 files)
# |- Segmented Control/ (80 files)
# |- Selection controls/ (935 files)
# |- Slider/ (80 files)
# |- Snackbar/ (64 files)
# |- Status/ (288 files)
# |- Super carousel/ (288 files)
# |- Super header/ (2304 files)
# |- Tab/ (672 files)
# |- Tag/ (256 files)
# |- Text Field/ (2560 files)
# |- Thumbnail/ (80 files)
# |- Tile/ (32 files)
# |- Tooltip/ (72 files)

# %% [markdown]
# ### 2-2. Adjusting Dataset Images
#
# The images in the dataset must be adjusted to match the input size of the model. For example, for MobileNetV3, the input size is 224x224x3, so the images in the dataset need to be adjusted to this size. The adjusted images are stored in the `ui_path` folder.

# %%
from PIL import Image

# Create the new directory if it doesn't exist
os.makedirs(ui_path, exist_ok=True)

# Get the list of all folders in the origin and screenshot paths
all_folders = set(os.listdir(origin_path) + os.listdir(screenshot_path))

# Loop through each folder in the list
for folder_name in all_folders:
    # Construct the full path to the origin and screenshot folders
    origin_folder_path = os.path.join(origin_path, folder_name)
    screenshot_folder_path = os.path.join(screenshot_path, folder_name)

    # Check if the origin and screenshot folders exist
    origin_exists = os.path.isdir(origin_folder_path)
    screenshot_exists = os.path.isdir(screenshot_folder_path)

    # If neither folder exists, skip this folder
    if not origin_exists and not screenshot_exists:
        print(f"Folder {folder_name} does not exist in either the origin or screenshot path. Please check the data.")
        continue

    # Get the list of files in the origin and screenshot folders
    origin_files = os.listdir(origin_folder_path) if origin_exists else []
    screenshot_files = os.listdir(screenshot_folder_path) if screenshot_exists else []

    # If the number of screenshot files is less than or equal to 200
    if len(screenshot_files) <= 200:
        # Calculate the number of files to select from the origin folder
        num_files_to_select = min(len(origin_files), 200-len(screenshot_files))

        # Randomly select files from the origin folder
        selected_origin_files = np.random.choice(origin_files, size=num_files_to_select, replace=False).tolist() if num_files_to_select > 0 else []
    else:
        print(f"Folder {folder_name} has more than 200 images. Please check the data.")
        continue

    # Combine the screenshot and selected origin files
    combined_files = screenshot_files + selected_origin_files

    # Shuffle the combined files
    np.random.shuffle(combined_files)

    # Create the new folder if it doesn't exist
    new_folder_path = os.path.join(ui_path, folder_name)
    os.makedirs(new_folder_path, exist_ok=True)
    
    # Loop through each file in the combined files
    for filename in combined_files:
        # Only process .png files
        if filename.endswith('.png'):
            # Check if the file is from the screenshot or origin folder
            if filename in screenshot_files:
                folder_path = screenshot_folder_path
            else:
                folder_path = origin_folder_path

            # Construct the full path to the file
            file_path = os.path.join(folder_path, filename)
            
            # Open the image file
            img = Image.open(file_path).convert("RGBA")
            
            # Get the width and height of the image
            width, height = img.size
            
            # Create a new square image with alpha channel
            new_image = Image.new('RGBA', (max(width, height), max(width, height)))
            
            # Paste the original image into the center of the new image
            new_image.paste(img, (int((new_image.width - img.width) / 2), int((new_image.height - img.height) / 2)))
            
            # Create a white background image
            bg = Image.new('RGBA', new_image.size, (255, 255, 255, 255))  # RGBA mode
            
            # Combine the new image with the white background
            final_image = Image.alpha_composite(bg, new_image)
            
            # Resize the final image to the target size
            final_image = final_image.resize(IMAGE_SIZE, Image.LANCZOS)
            
            # Construct the new file path
            new_file_path = os.path.join(new_folder_path, filename)
            
            # Save the new image as PNG
            final_image.save(new_file_path, format='PNG')
            
            # Print the result
            print(f"Saved new image at {new_file_path}")
# Out:
# Folder .DS_Store does not exist in either the origin or screenshot path. Please check the data.
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.04 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 148 - 644.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.18.25 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.17.56 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 26 - 26.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 35 - 531.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 134 - 630.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 34 - 114.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 5 - 85.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.23 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.18.18 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 15 - 511.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.11.45 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.34 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 79 - 239.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.07 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 26 - 1050.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 130 - 1010.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 188 - 348.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 3 - 499.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 66 - 66.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 159 - 319.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 157 - 317.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 2 - 498.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 44 - 44.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 121 - 1145.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.15.34 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 218 - 378.png
# Saved new image at ./dataset/ui/Card/Horizontal Standard _ v1.4 - 14 - 870.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.15.30 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Standard _ v1.4 - 20 - 876.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.17.35 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.18.12 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.12 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 50 - 1074.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 279 - 439.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 185 - 681.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 21 - 901.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 201 - 361.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.46 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 34 - 34.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 38 - 534.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 172 - 332.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 308 - 804.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 27 - 1051.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 31 - 111.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 52 - 212.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 29 - 909.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.17.04 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 14 - 14.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 142 - 302.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 46 - 542.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 82 - 578.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 286 - 446.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 56 - 216.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.41 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 95 - 1119.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 100 - 980.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 70 - 150.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.11.49 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 33 - 1057.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 181 - 341.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 256 - 752.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 316 - 476.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.18.03 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 29 - 525.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 220 - 716.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.15.15 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 309 - 469.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 326 - 822.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.36 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 64 - 944.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.17.07 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 16 - 512.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 201 - 697.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 250 - 410.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 138 - 1018.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 332 - 828.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 147 - 307.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 3 - 1027.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 233 - 729.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 115 - 1139.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.28 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 5 - 501.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.14.12 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 112 - 272.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 63 - 143.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 48 - 544.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.30 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 106 - 1130.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.14.46 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.42 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 109 - 269.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.15.03 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 6 - 86.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 12 - 172.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.33 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 13 - 1037.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.59 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 127 - 1151.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 212 - 372.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 33 - 193.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.22.34 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 221 - 717.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 6 - 886.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 245 - 405.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 113 - 273.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.11.55 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 335 - 495.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.18.41 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 69 - 565.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 164 - 660.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.19 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 41 - 121.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.16.50 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 106 - 266.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 278 - 438.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 95 - 255.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.17.21 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 89 - 585.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 135 - 295.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.14.35 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.14.03 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 298 - 458.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 186 - 682.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 23 - 903.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.15.06 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 23 - 103.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 259 - 419.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.18.28 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.15.23 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 271 - 431.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 131 - 1011.png
# Saved new image at ./dataset/ui/Card/Horizontal Standard _ v1.4 - 7 - 839.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 59 - 555.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 173 - 669.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 251 - 411.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 273 - 433.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 72 - 952.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.51 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 78 - 1102.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.27 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.17.12 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.23 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 273 - 769.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.17.49 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 120 - 1000.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 7 - 07.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.48 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 177 - 337.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.22.30 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.14.53 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.15.19 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 56 - 936.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.44 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 26 - 106.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 320 - 816.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 285 - 781.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.15.12 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 61 - 557.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 128 - 1152.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 106 - 986.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 77 - 157.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.14.08 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 134 - 1158.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 47 - 207.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 67 - 227.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.17.15 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 73 - 233.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.22.37 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 62 - 62.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.11.52 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 255 - 415.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 169 - 665.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.18.16 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 28 - 28.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 244 - 740.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.38 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.18.36 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 336 - 832.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 41 - 41.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 54 - 550.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 145 - 641.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 124 - 620.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 68 - 1092.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 170 - 330.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 254 - 750.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 65 - 145.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 118 - 278.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.12.00 AM.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 61 - 1085.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 197 - 357.png
# Saved new image at ./dataset/ui/Card/Vertical Standard _ v1.4 - 35 - 115.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.14.18 AM.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 269 - 765.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 231 - 727.png
# Saved new image at ./dataset/ui/Card/Horizontal Contained _ v1.4 - 89 - 1113.png
# Saved new image at ./dataset/ui/Card/Vertical Contained _ v1.4 - 213 - 373.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.14.59 AM.png
# Saved new image at ./dataset/ui/Card/Screenshot 2023-07-14 at 12.17.41 AM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 88.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 131.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 111.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.37.43 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 181.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 97.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.38.45 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 77.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 158.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 107.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 129.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.40.42 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 106.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 04.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 150.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 175.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 60.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 56.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 73.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.38.42 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 86.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.40.06 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 160.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 28.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 186.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 19.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 41.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 43.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 62.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 87.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 176.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 78.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 125.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.39.05 PM.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.38.55 PM.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.38.40 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 51.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 179.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 79.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 33.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 96.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 103.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 12.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 189.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 54.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 156.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 64.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 142.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.39.03 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 46.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 188.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 170.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 147.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 174.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 166.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 61.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 66.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 13.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 168.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 44.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 133.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 70.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 83.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 80.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 167.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 130.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 155.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 55.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 119.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 57.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 22.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 50.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 75.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 85.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 45.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 169.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 116.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 47.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 30.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 20.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 165.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 162.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 173.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 14.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 163.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 38.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 153.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 26.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 128.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.40.15 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 94.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 07.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 59.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 65.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 49.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 137.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 141.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 127.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 67.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 126.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 112.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.40.49 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 71.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 34.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 29.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 117.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 118.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 72.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 135.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 148.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 109.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 10.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 102.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 149.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 143.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 177.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 154.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.38.50 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 132.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 100.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 182.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 01.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 105.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 74.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 161.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 23.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 24.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 171.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 03.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 21.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.40.52 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 95.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 02.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 114.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 09.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 05.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.38.22 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 15.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 08.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 136.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 99.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 37.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 122.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 113.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 101.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 25.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 81.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 31.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.38.58 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 121.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 192.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.40.37 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 63.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 40.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 178.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 144.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.40.31 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 11.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 06.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 84.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 76.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 115.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 191.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 120.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 184.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 157.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 172.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 58.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 48.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 151.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 16.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 108.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 36.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 89.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 82.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 190.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 152.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 39.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.40.11 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 140.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 183.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 124.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 164.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 68.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 93.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 180.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.39.00 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 123.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 92.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 187.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 69.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 134.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 90.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 91.png
# Saved new image at ./dataset/ui/Modal loader/Screenshot 2023-07-16 at 11.38.47 PM.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 138.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 52.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 35.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 17.png
# Saved new image at ./dataset/ui/Modal loader/Modal loader _ v1.0 - 42.png
# Saved new image at ./dataset/ui/Icon/34138_006.png
# Saved new image at ./dataset/ui/Icon/28_002.png
# Saved new image at ./dataset/ui/Icon/95_005.png
# Saved new image at ./dataset/ui/Icon/12922_023.png
# Saved new image at ./dataset/ui/Icon/95_027.png
# Saved new image at ./dataset/ui/Icon/37431_001.png
# Saved new image at ./dataset/ui/Icon/9079_002.png
# Saved new image at ./dataset/ui/Icon/323_005.png
# Saved new image at ./dataset/ui/Icon/37556_006.png
# Saved new image at ./dataset/ui/Icon/30138_001.png
# Saved new image at ./dataset/ui/Icon/137_004.png
# Saved new image at ./dataset/ui/Icon/4797_008.png
# Saved new image at ./dataset/ui/Icon/6896_008.png
# Saved new image at ./dataset/ui/Icon/30341_008.png
# Saved new image at ./dataset/ui/Icon/13764_022.png
# Saved new image at ./dataset/ui/Icon/27549_022.png
# Saved new image at ./dataset/ui/Icon/95_008.png
# Saved new image at ./dataset/ui/Icon/8267_013.png
# Saved new image at ./dataset/ui/Icon/9_005.png
# Saved new image at ./dataset/ui/Icon/54833_024.png
# Saved new image at ./dataset/ui/Icon/6211_016.png
# Saved new image at ./dataset/ui/Icon/28333_006.png
# Saved new image at ./dataset/ui/Icon/49055_002.png
# Saved new image at ./dataset/ui/Icon/95_013.png
# Saved new image at ./dataset/ui/Icon/44522_031.png
# Saved new image at ./dataset/ui/Icon/31138_014.png
# Saved new image at ./dataset/ui/Icon/8267_014.png
# Saved new image at ./dataset/ui/Icon/28531_020.png
# Saved new image at ./dataset/ui/Icon/12810_001.png
# Saved new image at ./dataset/ui/Icon/95_005.png
# Saved new image at ./dataset/ui/Icon/31475_018.png
# Saved new image at ./dataset/ui/Icon/100_001.png
# Saved new image at ./dataset/ui/Icon/257_001.png
# Saved new image at ./dataset/ui/Icon/95_002.png
# Saved new image at ./dataset/ui/Icon/8945_018.png
# Saved new image at ./dataset/ui/Icon/30122_012.png
# Saved new image at ./dataset/ui/Icon/13764_001.png
# Saved new image at ./dataset/ui/Icon/59682_016.png
# Saved new image at ./dataset/ui/Icon/44287_020.png
# Saved new image at ./dataset/ui/Icon/65550_004.png
# Saved new image at ./dataset/ui/Icon/41568_023.png
# Saved new image at ./dataset/ui/Icon/1050_001.png
# Saved new image at ./dataset/ui/Icon/63779_004.png
# Saved new image at ./dataset/ui/Icon/228_022.png
# Saved new image at ./dataset/ui/Icon/28531_012.png
# Saved new image at ./dataset/ui/Icon/19083_017.png
# Saved new image at ./dataset/ui/Icon/95_022.png
# Saved new image at ./dataset/ui/Icon/8932_020.png
# Saved new image at ./dataset/ui/Icon/1072_016.png
# Saved new image at ./dataset/ui/Icon/7554_005.png
# Saved new image at ./dataset/ui/Icon/1072_025.png
# Saved new image at ./dataset/ui/Icon/3207_002.png
# Saved new image at ./dataset/ui/Icon/53873_012.png
# Saved new image at ./dataset/ui/Icon/41025_012.png
# Saved new image at ./dataset/ui/Icon/132_001.png
# Saved new image at ./dataset/ui/Icon/1220_005.png
# Saved new image at ./dataset/ui/Icon/95_028.png
# Saved new image at ./dataset/ui/Icon/95_020.png
# Saved new image at ./dataset/ui/Icon/8932_023.png
# Saved new image at ./dataset/ui/Icon/305_008.png
# Saved new image at ./dataset/ui/Icon/26654_008.png
# Saved new image at ./dataset/ui/Icon/17223_004.png
# Saved new image at ./dataset/ui/Icon/20209_012.png
# Saved new image at ./dataset/ui/Icon/95_019.png
# Saved new image at ./dataset/ui/Icon/12928_022.png
# Saved new image at ./dataset/ui/Icon/29820_014.png
# Saved new image at ./dataset/ui/Icon/205_003.png
# Saved new image at ./dataset/ui/Icon/55848_011.png
# Saved new image at ./dataset/ui/Icon/29_006.png
# Saved new image at ./dataset/ui/Icon/33175_018.png
# Saved new image at ./dataset/ui/Icon/36779_007.png
# Saved new image at ./dataset/ui/Icon/28000_004.png
# Saved new image at ./dataset/ui/Icon/40834_012.png
# Saved new image at ./dataset/ui/Icon/2583_006.png
# Saved new image at ./dataset/ui/Icon/108_013.png
# Saved new image at ./dataset/ui/Icon/54472_007.png
# Saved new image at ./dataset/ui/Icon/18324_004.png
# Saved new image at ./dataset/ui/Icon/370_006.png
# Saved new image at ./dataset/ui/Icon/12928_019.png
# Saved new image at ./dataset/ui/Icon/37431_010.png
# Saved new image at ./dataset/ui/Icon/59605_001.png
# Saved new image at ./dataset/ui/Icon/327_008.png
# Saved new image at ./dataset/ui/Icon/95_023.png
# Saved new image at ./dataset/ui/Icon/295_038.png
# Saved new image at ./dataset/ui/Icon/29812_012.png
# Saved new image at ./dataset/ui/Icon/3859_013.png
# Saved new image at ./dataset/ui/Icon/95_010.png
# Saved new image at ./dataset/ui/Icon/8945_017.png
# Saved new image at ./dataset/ui/Icon/16810_010.png
# Saved new image at ./dataset/ui/Icon/1215_032.png
# Saved new image at ./dataset/ui/Icon/382_006.png
# Saved new image at ./dataset/ui/Icon/37121_011.png
# Saved new image at ./dataset/ui/Icon/6727_010.png
# Saved new image at ./dataset/ui/Icon/38459_003.png
# Saved new image at ./dataset/ui/Icon/95_017.png
# Saved new image at ./dataset/ui/Icon/34222_024.png
# Saved new image at ./dataset/ui/Icon/35714_003.png
# Saved new image at ./dataset/ui/Icon/25921_014.png
# Saved new image at ./dataset/ui/Icon/28284_004.png
# Saved new image at ./dataset/ui/Icon/3843_011.png
# Saved new image at ./dataset/ui/Icon/321_005.png
# Saved new image at ./dataset/ui/Icon/295_017.png
# Saved new image at ./dataset/ui/Icon/100_002.png
# Saved new image at ./dataset/ui/Icon/8932_024.png
# Saved new image at ./dataset/ui/Icon/32951_011.png
# Saved new image at ./dataset/ui/Icon/17470_006.png
# Saved new image at ./dataset/ui/Icon/29_009.png
# Saved new image at ./dataset/ui/Icon/95_019.png
# Saved new image at ./dataset/ui/Icon/95_025.png
# Saved new image at ./dataset/ui/Icon/29_004.png
# Saved new image at ./dataset/ui/Icon/40546_010.png
# Saved new image at ./dataset/ui/Icon/29709_006.png
# Saved new image at ./dataset/ui/Icon/1441_004.png
# Saved new image at ./dataset/ui/Icon/48790_005.png
# Saved new image at ./dataset/ui/Icon/25731_015.png
# Saved new image at ./dataset/ui/Icon/69256_006.png
# Saved new image at ./dataset/ui/Icon/28_003.png
# Saved new image at ./dataset/ui/Icon/325_009.png
# Saved new image at ./dataset/ui/Icon/45863_015.png
# Saved new image at ./dataset/ui/Icon/28924_006.png
# Saved new image at ./dataset/ui/Icon/30121_022.png
# Saved new image at ./dataset/ui/Icon/29_005.png
# Saved new image at ./dataset/ui/Icon/41036_016.png
# Saved new image at ./dataset/ui/Icon/22032_010.png
# Saved new image at ./dataset/ui/Icon/4686_004.png
# Saved new image at ./dataset/ui/Icon/28642_019.png
# Saved new image at ./dataset/ui/Icon/29765_015.png
# Saved new image at ./dataset/ui/Icon/31172_004.png
# Saved new image at ./dataset/ui/Icon/48577_017.png
# Saved new image at ./dataset/ui/Icon/40810_002.png
# Saved new image at ./dataset/ui/Icon/12946_021.png
# Saved new image at ./dataset/ui/Icon/40546_011.png
# Saved new image at ./dataset/ui/Icon/28_005.png
# Saved new image at ./dataset/ui/Icon/4755_005.png
# Saved new image at ./dataset/ui/Icon/7_015.png
# Saved new image at ./dataset/ui/Icon/28896_007.png
# Saved new image at ./dataset/ui/Icon/35600_010.png
# Saved new image at ./dataset/ui/Icon/8371_014.png
# Saved new image at ./dataset/ui/Icon/23618_017.png
# Saved new image at ./dataset/ui/Icon/95_011.png
# Saved new image at ./dataset/ui/Icon/8948_020.png
# Saved new image at ./dataset/ui/Icon/14584_018.png
# Saved new image at ./dataset/ui/Icon/35714_017.png
# Saved new image at ./dataset/ui/Icon/24504_003.png
# Saved new image at ./dataset/ui/Icon/29750_003.png
# Saved new image at ./dataset/ui/Icon/10244_005.png
# Saved new image at ./dataset/ui/Icon/7_019.png
# Saved new image at ./dataset/ui/Icon/21117_012.png
# Saved new image at ./dataset/ui/Icon/14584_017.png
# Saved new image at ./dataset/ui/Icon/13334_015.png
# Saved new image at ./dataset/ui/Icon/60403_004.png
# Saved new image at ./dataset/ui/Icon/56280_001.png
# Saved new image at ./dataset/ui/Icon/32473_011.png
# Saved new image at ./dataset/ui/Icon/12926_006.png
# Saved new image at ./dataset/ui/Icon/95_023.png
# Saved new image at ./dataset/ui/Icon/295_038.png
# Saved new image at ./dataset/ui/Icon/9_005.png
# Saved new image at ./dataset/ui/Icon/108_011.png
# Saved new image at ./dataset/ui/Icon/295_008.png
# Saved new image at ./dataset/ui/Icon/295_004.png
# Saved new image at ./dataset/ui/Icon/33579_012.png
# Saved new image at ./dataset/ui/Icon/4144_009.png
# Saved new image at ./dataset/ui/Icon/13281_013.png
# Saved new image at ./dataset/ui/Icon/41680_016.png
# Saved new image at ./dataset/ui/Icon/8_016.png
# Saved new image at ./dataset/ui/Icon/29_003.png
# Saved new image at ./dataset/ui/Icon/24659_021.png
# Saved new image at ./dataset/ui/Icon/6402_002.png
# Saved new image at ./dataset/ui/Icon/62469_004.png
# Saved new image at ./dataset/ui/Icon/31145_005.png
# Saved new image at ./dataset/ui/Icon/28_003.png
# Saved new image at ./dataset/ui/Icon/9_003.png
# Saved new image at ./dataset/ui/Icon/7868_005.png
# Saved new image at ./dataset/ui/Icon/95_004.png
# Saved new image at ./dataset/ui/Icon/31142_011.png
# Saved new image at ./dataset/ui/Icon/40563_003.png
# Saved new image at ./dataset/ui/Icon/95_014.png
# Saved new image at ./dataset/ui/Icon/13415_006.png
# Saved new image at ./dataset/ui/Icon/31151_012.png
# Saved new image at ./dataset/ui/Icon/1491_009.png
# Saved new image at ./dataset/ui/Icon/2500_013.png
# Saved new image at ./dataset/ui/Icon/56785_016.png
# Saved new image at ./dataset/ui/Icon/27239_003.png
# Saved new image at ./dataset/ui/Icon/13766_010.png
# Saved new image at ./dataset/ui/Icon/132_002.png
# Saved new image at ./dataset/ui/Icon/53768_003.png
# Saved new image at ./dataset/ui/Icon/32951_012.png
# Saved new image at ./dataset/ui/Icon/6208_012.png
# Saved new image at ./dataset/ui/Icon/27238_020.png
# Saved new image at ./dataset/ui/Icon/137_001.png
# Saved new image at ./dataset/ui/Icon/63783_009.png
# Saved new image at ./dataset/ui/Icon/63912_001.png
# Saved new image at ./dataset/ui/Icon/36191_015.png
# Saved new image at ./dataset/ui/Icon/63774_004.png
# Saved new image at ./dataset/ui/Icon/295_012.png
# Saved new image at ./dataset/ui/Icon/3425_007.png
# Saved new image at ./dataset/ui/Icon/59605_007.png
# Saved new image at ./dataset/ui/Icon/10624_001.png
# Saved new image at ./dataset/ui/Icon/40234_006.png
# Saved new image at ./dataset/ui/Icon/52991_004.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 215.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 130.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 385.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 95.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 257.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 58.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 200.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 340.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 119.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 258.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 279.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 63.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 341.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 154.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 184.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 299.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 262.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 267.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 194.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 417.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 408.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 32.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 221.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 342.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 374.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 362.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 136.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 328.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 339.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 196.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 321.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 51.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 315.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 65.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 208.png
# Saved new image at ./dataset/ui/Filter and sort/Screenshot 2023-07-16 at 10.44.17 PM.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 189.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 190.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 169.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 386.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 77.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 23.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 213.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 133.png
# Saved new image at ./dataset/ui/Filter and sort/Screenshot 2023-07-16 at 10.45.13 PM.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 150.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 28.png
# Saved new image at ./dataset/ui/Filter and sort/Screenshot 2023-07-16 at 10.44.27 PM.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 376.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 31.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 296.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 234.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 183.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 177.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 265.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 172.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 345.png
# Saved new image at ./dataset/ui/Filter and sort/Screenshot 2023-07-16 at 10.46.43 PM.png
# Saved new image at ./dataset/ui/Filter and sort/Screenshot 2023-07-16 at 10.45.19 PM.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 245.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 426.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 140.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 294.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 261.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 80.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 209.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 409.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 270.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 419.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 284.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 40.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 323.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 331.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 254.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 406.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 273.png
# Saved new image at ./dataset/ui/Filter and sort/Screenshot 2023-07-16 at 10.46.48 PM.png
# Saved new image at ./dataset/ui/Filter and sort/Screenshot 2023-07-16 at 10.46.17 PM.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 214.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 312.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 07.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 301.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 188.png
# Saved new image at ./dataset/ui/Filter and sort/Screenshot 2023-07-16 at 10.42.38 PM.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 93.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 217.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 239.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 287.png
# Saved new image at ./dataset/ui/Filter and sort/Filter and sort _ ❖ - 240.png
# ...
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 91 - 115.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 97 - 121.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 87 - 219.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 62 - 86.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 92 - 116.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 5 - 17.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 20 - 284.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 56 - 80.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 33 - 57.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 3 - 243.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 25 - 49.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 57 - 189.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 90 - 114.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 71 - 203.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 56 - 188.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 12 - 144.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 38 - 62.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 9 - 273.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 7 - 247.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 102 - 234.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 6 - 270.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 81 - 105.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 84 - 216.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 86 - 110.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 51 - 75.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 3 - 27.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 34 - 58.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 3 - 15.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 52 - 184.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 55 - 79.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 14 - 146.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 11 - 275.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 23 - 263.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 46 - 178.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 12 - 252.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 23 - 47.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 6 - 246.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 18 - 282.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 101 - 125.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 9 - 33.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 98 - 122.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 63 - 195.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 8 - 248.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 33 - 165.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 53 - 77.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 36 - 168.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 8 - 32.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 87 - 111.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 6 - 138.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 10 - 142.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 29 - 53.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 27 - 159.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 61 - 85.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 70 - 202.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 43 - 175.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 19 - 151.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 72 - 204.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 88 - 220.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 17 - 149.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 60 - 84.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 16 - 148.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 15 - 39.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 104 - 236.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 11 - 251.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 103 - 127.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 28 - 52.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 9 - 141.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 51 - 183.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 82 - 214.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 47 - 179.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 21 - 45.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 5 - 245.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 57 - 81.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 1 - 01.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 28 - 160.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 89 - 221.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 12 - 36.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 93 - 225.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 3 - 03.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 21 - 261.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 53 - 185.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 7 - 07.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 105 - 129.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 4 - 268.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 8 - 272.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 45 - 177.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 65 - 197.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 24 - 48.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 18 - 42.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 19 - 259.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 79 - 211.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 19 - 43.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 103 - 235.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 3 - 135.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 68 - 92.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 75 - 207.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 13 - 277.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 46 - 70.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 95 - 119.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 62 - 194.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 37 - 169.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 2 - 14.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 14 - 38.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 60 - 192.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 50 - 74.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 20 - 152.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 100 - 232.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 36 - 60.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 80 - 104.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 40 - 64.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 10 - 10.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 5 - 269.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 21 - 285.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 20 - 44.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 42 - 174.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 55 - 187.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 48 - 72.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 86 - 218.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 3 - 267.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 49 - 181.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 2 - 02.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 47 - 71.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 96 - 228.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 23 - 155.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 88 - 112.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 35 - 59.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 80 - 212.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 77 - 209.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 42 - 66.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 64 - 196.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 65 - 89.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 54 - 78.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 26 - 158.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 9 - 09.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 11 - 143.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 39 - 171.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 8 - 20.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 14 - 254.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 67 - 91.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 81 - 213.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 7 - 19.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 8 - 140.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 13 - 37.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 85 - 109.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 59 - 191.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 24 - 288.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 4 - 136.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 69 - 201.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 73 - 97.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 14 - 278.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 7 - 139.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 72 - 96.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 11 - 11.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 4 - 28.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 64 - 88.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 93 - 117.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 23 - 287.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 63 - 87.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 94 - 118.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 15 - 279.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 85 - 217.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 79 - 103.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 10 - 250.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 108 - 240.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 2 - 266.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 4 - 16.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 24 - 264.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 44 - 176.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Accordion _ v1.5 - 10 - 274.png
# Saved new image at ./dataset/ui/Section Header/Section Header - Default _ v1.5 - 92 - 224.png

# %%
# Draw the folder tree of the ui_path directory
print('UI structure:')
draw_folder_tree(ui_path)
# Out:
# UI structure:
# |- Accordion/ (200 files)
# |- App Bar/ (200 files)
# |- Avatar/ (58 files)
# |- Badge/ (200 files)
# |- Banner/ (200 files)
# |- Bottom navigation/ (136 files)
# |- Bottom sheet/ (200 files)
# |- Buttons/ (200 files)
# |- Card/ (200 files)
# |- Dropdown/ (200 files)
# |- Enter amount/ (200 files)
# |- Filter and sort/ (200 files)
# |- Icon/ (194 files)
# |- Link/ (200 files)
# |- List items/ (200 files)
# |- Modal loader/ (200 files)
# |- Nudge/ (200 files)
# |- OTP/ (200 files)
# |- Onboarding Stories/ (200 files)
# |- Progress Tracker/ (200 files)
# |- Quick Actions/ (132 files)
# |- Quick Select/ (200 files)
# |- Section Header/ (200 files)
# |- Segmented Control/ (80 files)
# |- Selection controls/ (200 files)
# |- Slider/ (80 files)
# |- Snackbar/ (121 files)
# |- Status/ (200 files)
# |- Super carousel/ (200 files)
# |- Super header/ (200 files)
# |- Tab/ (200 files)
# |- Tag/ (200 files)
# |- Text Field/ (200 files)
# |- Thumbnail/ (80 files)
# |- Tile/ (32 files)
# |- Tooltip/ (90 files)

# %% [markdown]
# ### 2-3. Converting to TensorFlow Dataset
#
# Finally, use the `image_dataset_from_directory` function in TensorFlow to convert the `ui_path` folder into a TensorFlow dataset. This converted dataset is used for model training.

# %%
def build_dataset(subset):
  return tf.keras.preprocessing.image_dataset_from_directory(
      ui_path,
      validation_split=.20,
      subset=subset,
      label_mode="categorical",
      # Seed needs to provided when using validation_split and shuffle = True.
      # A fixed seed is used so that the validation set is stable across runs.
      seed=123,
      image_size=IMAGE_SIZE,
      batch_size=1)

train_ds = build_dataset("training")
class_names = tuple(train_ds.class_names)
train_size = train_ds.cardinality().numpy()
train_ds = train_ds.unbatch().batch(BATCH_SIZE)
train_ds = train_ds.repeat()

normalization_layer = tf.keras.layers.Rescaling(1. / 255)
preprocessing_model = tf.keras.Sequential([normalization_layer])
do_data_augmentation = False #@param {type:"boolean"}
if do_data_augmentation:
  preprocessing_model.add(
      tf.keras.layers.RandomRotation(40))
  preprocessing_model.add(
      tf.keras.layers.RandomTranslation(0, 0.2))
  preprocessing_model.add(
      tf.keras.layers.RandomTranslation(0.2, 0))
  # Like the old tf.keras.preprocessing.image.ImageDataGenerator(),
  # image sizes are fixed when reading, and then a random zoom is applied.
  # If all training inputs are larger than image_size, one could also use
  # RandomCrop with a batch size of 1 and rebatch later.
  preprocessing_model.add(
      tf.keras.layers.RandomZoom(0.2, 0.2))
  preprocessing_model.add(
      tf.keras.layers.RandomFlip(mode="horizontal"))
train_ds = train_ds.map(lambda images, labels:
                        (preprocessing_model(images), labels))

val_ds = build_dataset("validation")
valid_size = val_ds.cardinality().numpy()
val_ds = val_ds.unbatch().batch(BATCH_SIZE)
val_ds = val_ds.map(lambda images, labels:
                    (normalization_layer(images), labels))
# Out:
# Found 6203 files belonging to 36 classes.
# Using 4963 files for training.
# Found 6203 files belonging to 36 classes.
# Using 1240 files for validation.

# %% [markdown]
# ## 3. Training
#
# ### 3-1. Defining the model
#
# All it takes is to put a linear classifier on top of the feature_extractor_layer with the Hub module.
#
# For speed, we start out with a non-trainable feature_extractor_layer, but you can also enable fine-tuning for greater accuracy.

# %%
do_fine_tuning = False #@param {type:"boolean"}

# %%
print("Building model with", model_handle)
model = tf.keras.Sequential([
    # Explicitly define the input shape so the model can be properly
    # loaded by the TFLiteConverter
    tf.keras.layers.InputLayer(input_shape=IMAGE_SIZE + (3,)),
    hub.KerasLayer(model_handle, trainable=do_fine_tuning),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(len(class_names),
                          kernel_regularizer=tf.keras.regularizers.l2(0.0001))
])
model.build((None,)+IMAGE_SIZE+(3,))
model.summary()
# Out:
# Building model with https://tfhub.dev/google/imagenet/mobilenet_v3_small_100_224/feature_vector/5
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1024)              1529968
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 36)                36900
#
# =================================================================
# Total params: 1566868 (5.98 MB)
# Trainable params: 36900 (144.14 KB)
# Non-trainable params: 1529968 (5.84 MB)
# _________________________________________________________________

# %% [markdown]
# ### 3-2. Training the model

# %%
model.compile(
  optimizer=tf.keras.optimizers.legacy.SGD(learning_rate=0.005, momentum=0.9), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])

# %%
steps_per_epoch = train_size // BATCH_SIZE
validation_steps = valid_size // BATCH_SIZE
hist = model.fit(
    train_ds,
    epochs=5, steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,
    validation_steps=validation_steps).history
# Out:
# Epoch 1/5
# 310/310 [==============================] - 16s 45ms/step - loss: 1.7216 - accuracy: 0.7095 - val_loss: 1.2750 - val_accuracy: 0.8393
# Epoch 2/5
# 310/310 [==============================] - 14s 43ms/step - loss: 1.1550 - accuracy: 0.8951 - val_loss: 1.1324 - val_accuracy: 0.8839
# Epoch 3/5
# 310/310 [==============================] - 13s 43ms/step - loss: 1.0582 - accuracy: 0.9222 - val_loss: 1.0667 - val_accuracy: 0.9107
# Epoch 4/5
# 310/310 [==============================] - 13s 43ms/step - loss: 1.0088 - accuracy: 0.9327 - val_loss: 1.0292 - val_accuracy: 0.9253
# Epoch 5/5
# 310/310 [==============================] - 13s 43ms/step - loss: 0.9750 - accuracy: 0.9460 - val_loss: 1.0043 - val_accuracy: 0.9278

# %% [markdown]
# ### 3-3. Monitoring training progress

# %%
plt.figure()
plt.ylabel("Loss (training and validation)")
plt.xlabel("Training Steps")
plt.ylim([0,2])
plt.plot(hist["loss"])
plt.plot(hist["val_loss"])

plt.figure()
plt.ylabel("Accuracy (training and validation)")
plt.xlabel("Training Steps")
plt.ylim([0,1])
plt.plot(hist["accuracy"])
plt.plot(hist["val_accuracy"])

# %% [markdown]
# ### 3-4. Testing the custom trained model

# %%
x, y = next(iter(val_ds))
image = x[0, :, :, :]
true_index = np.argmax(y[0])
plt.imshow(image)
plt.axis('off')
plt.show()

# Expand the validation image to (1, 224, 224, 3) before predicting the label
prediction_scores = model.predict(np.expand_dims(image, axis=0))
predicted_index = np.argmax(prediction_scores)
print("True label: " + class_names[true_index])
print("Predicted label: " + class_names[predicted_index])
# Out:
# 1/1 [==============================] - 1s 924ms/step
# True label: Avatar
# Predicted label: Avatar

# %% [markdown]
# ## 4. Save and convert the model
#
# Finally, you can save the trained model to deploy it to TF Serving or TFJS as follows.
#
# ### 4-1. Saving the model

# %%
saved_model_path = f"{root_path}saved_model/{model_name}"
tf.saved_model.save(model, saved_model_path)
# Out:
# INFO:tensorflow:Assets written to: ./dataset/saved_model/mobilenet_v3_small_100_224/assets
# INFO:tensorflow:Assets written to: ./dataset/saved_model/mobilenet_v3_small_100_224/assets

# %% [markdown]
# ### 4-2 Convert Saved_model to TFJS
#
# Now that we have a trained model, we can convert it to TFJS format for use in the browser. We will use the `tensorflowjs_converter` to do this.

# %%
# set the path to the tfjs model
tfjs_model_path = f"{root_path}tfjs_model/{model_name}"

# convert the tf_saved_model to tfjs model via tensorflowjs_converter

# !tensorflowjs_converter --input_format=tf_saved_model {saved_model_path} {tfjs_model_path} --output_format=tfjs_graph_model

# %%
import os
import json

# List all folders in ui_path
folder_names = [entry.name for entry in os.scandir(ui_path) if entry.is_dir()]

# Generate labels list
labels = [{"name": name, "id": i+1} for i, name in enumerate(sorted(folder_names))]

print(labels)

# Write to metadata.json under the tfjs_model_path
with open(os.path.join(tfjs_model_path, "metadata.json"), "w") as f:
    json.dump({"labels": labels}, f)
# Out:
# [{'name': 'Accordion', 'id': 1}, {'name': 'App Bar', 'id': 2}, {'name': 'Avatar', 'id': 3}, {'name': 'Badge', 'id': 4}, {'name': 'Banner', 'id': 5}, {'name': 'Bottom navigation', 'id': 6}, {'name': 'Bottom sheet', 'id': 7}, {'name': 'Buttons', 'id': 8}, {'name': 'Card', 'id': 9}, {'name': 'Dropdown', 'id': 10}, {'name': 'Enter amount', 'id': 11}, {'name': 'Filter and sort', 'id': 12}, {'name': 'Icon', 'id': 13}, {'name': 'Link', 'id': 14}, {'name': 'List items', 'id': 15}, {'name': 'Modal loader', 'id': 16}, {'name': 'Nudge', 'id': 17}, {'name': 'OTP', 'id': 18}, {'name': 'Onboarding Stories', 'id': 19}, {'name': 'Progress Tracker', 'id': 20}, {'name': 'Quick Actions', 'id': 21}, {'name': 'Quick Select', 'id': 22}, {'name': 'Section Header', 'id': 23}, {'name': 'Segmented Control', 'id': 24}, {'name': 'Selection controls', 'id': 25}, {'name': 'Slider', 'id': 26}, {'name': 'Snackbar', 'id': 27}, {'name': 'Status', 'id': 28}, {'name': 'Super carousel', 'id': 29}, {'name': 'Super header', 'id': 30}, {'name': 'Tab', 'id': 31}, {'name': 'Tag', 'id': 32}, {'name': 'Text Field', 'id': 33}, {'name': 'Thumbnail', 'id': 34}, {'name': 'Tile', 'id': 35}, {'name': 'Tooltip', 'id': 36}]
