# %% [markdown]
# # Transfer Learning and Fine-tuning Image Classifier for UI Data Classification

# %% [markdown]
# Image classification models consist of millions of parameters. Training them from scratch requires a large amount of labeled training data and substantial computing power. Transfer learning is a technique that reduces this resource consumption by reusing parts of a model already trained on a related task in a new model.
#
# This Colab notebook aims to create a model for classifying UI data. It performs image feature extraction using a pre-trained TF2 SavedModel from TensorFlow Hub (trained on a larger and more general ImageNet dataset), and builds a Keras model to classify the UI data based on this. Additionally, it includes the process of fine-tuning the feature extractor with the newly added classifier.
#
# Finally, this model is converted for TFJS, making it easily usable on the web.
#
# This notebook was created by reworking [Google's official tutorial document](https://www.tensorflow.org/hub/tutorials/tf2_image_retraining?hl=ko).

# %% [markdown]
# ## 1. Setup
# ### 1-1. Importing Libraries

# %%
import itertools
import os

import matplotlib.pylab as plt
import numpy as np

import tensorflow as tf
import tensorflow_hub as hub

print("TF version:", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TF version: 2.14.0
# Hub version: 0.16.0.dev
# GPU is available

# %% [markdown]
# ### 1-2. Selecting a TF2 SavedModel Module
#
# In this notebook, we use the [https://tfhub.dev/google/imagenet/mobilenet_v3_small_100_224/feature_vector/5](https://tfhub.dev/google/imagenet/mobilenet_v3_small_100_224/feature_vector/5) model by default. This URL can be used in the code to identify the SavedModel and display its documentation in the browser.
#
# You can choose from various models. You can find more TF2 models that generate image feature vectors [here](https://tfhub.dev/s?module-type=image-feature-vector&tf-version=tf2).
#
# > **Note**: Although TensorFlow Hub has moved to [Kaggle Models](https://www.kaggle.com/models), you can still use the models in the same way as before.

# %%
#@title

model_name = "mobilenet_v2_140_224" # @param ['efficientnetv2-s', 'efficientnetv2-m', 'efficientnetv2-l', 'efficientnetv2-s-21k', 'efficientnetv2-m-21k', 'efficientnetv2-l-21k', 'efficientnetv2-xl-21k', 'efficientnetv2-b0-21k', 'efficientnetv2-b1-21k', 'efficientnetv2-b2-21k', 'efficientnetv2-b3-21k', 'efficientnetv2-s-21k-ft1k', 'efficientnetv2-m-21k-ft1k', 'efficientnetv2-l-21k-ft1k', 'efficientnetv2-xl-21k-ft1k', 'efficientnetv2-b0-21k-ft1k', 'efficientnetv2-b1-21k-ft1k', 'efficientnetv2-b2-21k-ft1k', 'efficientnetv2-b3-21k-ft1k', 'efficientnetv2-b0', 'efficientnetv2-b1', 'efficientnetv2-b2', 'efficientnetv2-b3', 'efficientnet_b0', 'efficientnet_b1', 'efficientnet_b2', 'efficientnet_b3', 'efficientnet_b4', 'efficientnet_b5', 'efficientnet_b6', 'efficientnet_b7', 'bit_s-r50x1', 'inception_v3', 'inception_resnet_v2', 'resnet_v1_50', 'resnet_v1_101', 'resnet_v1_152', 'resnet_v2_50', 'resnet_v2_101', 'resnet_v2_152', 'nasnet_large', 'nasnet_mobile', 'pnasnet_large', 'mobilenet_v2_100_224', 'mobilenet_v2_130_224', 'mobilenet_v2_140_224', 'mobilenet_v3_small_100_224', 'mobilenet_v3_small_075_224', 'mobilenet_v3_large_100_224', 'mobilenet_v3_large_075_224']

model_handle_map = {
  "efficientnetv2-s": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_s/feature_vector/2",
  "efficientnetv2-m": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_m/feature_vector/2",
  "efficientnetv2-l": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_l/feature_vector/2",
  "efficientnetv2-s-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_s/feature_vector/2",
  "efficientnetv2-m-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_m/feature_vector/2",
  "efficientnetv2-l-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_l/feature_vector/2",
  "efficientnetv2-xl-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_xl/feature_vector/2",
  "efficientnetv2-b0-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b0/feature_vector/2",
  "efficientnetv2-b1-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b1/feature_vector/2",
  "efficientnetv2-b2-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b2/feature_vector/2",
  "efficientnetv2-b3-21k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b3/feature_vector/2",
  "efficientnetv2-s-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_s/feature_vector/2",
  "efficientnetv2-m-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_m/feature_vector/2",
  "efficientnetv2-l-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_l/feature_vector/2",
  "efficientnetv2-xl-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_xl/feature_vector/2",
  "efficientnetv2-b0-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_b0/feature_vector/2",
  "efficientnetv2-b1-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_b1/feature_vector/2",
  "efficientnetv2-b2-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_b2/feature_vector/2",
  "efficientnetv2-b3-21k-ft1k": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_ft1k_b3/feature_vector/2",
  "efficientnetv2-b0": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b0/feature_vector/2",
  "efficientnetv2-b1": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b1/feature_vector/2",
  "efficientnetv2-b2": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b2/feature_vector/2",
  "efficientnetv2-b3": "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b3/feature_vector/2",
  "efficientnet_b0": "https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1",
  "efficientnet_b1": "https://tfhub.dev/tensorflow/efficientnet/b1/feature-vector/1",
  "efficientnet_b2": "https://tfhub.dev/tensorflow/efficientnet/b2/feature-vector/1",
  "efficientnet_b3": "https://tfhub.dev/tensorflow/efficientnet/b3/feature-vector/1",
  "efficientnet_b4": "https://tfhub.dev/tensorflow/efficientnet/b4/feature-vector/1",
  "efficientnet_b5": "https://tfhub.dev/tensorflow/efficientnet/b5/feature-vector/1",
  "efficientnet_b6": "https://tfhub.dev/tensorflow/efficientnet/b6/feature-vector/1",
  "efficientnet_b7": "https://tfhub.dev/tensorflow/efficientnet/b7/feature-vector/1",
  "bit_s-r50x1": "https://tfhub.dev/google/bit/s-r50x1/1",
  "inception_v3": "https://tfhub.dev/google/imagenet/inception_v3/feature-vector/4",
  "inception_resnet_v2": "https://tfhub.dev/google/imagenet/inception_resnet_v2/feature-vector/4",
  "resnet_v1_50": "https://tfhub.dev/google/imagenet/resnet_v1_50/feature-vector/4",
  "resnet_v1_101": "https://tfhub.dev/google/imagenet/resnet_v1_101/feature-vector/4",
  "resnet_v1_152": "https://tfhub.dev/google/imagenet/resnet_v1_152/feature-vector/4",
  "resnet_v2_50": "https://tfhub.dev/google/imagenet/resnet_v2_50/feature-vector/4",
  "resnet_v2_101": "https://tfhub.dev/google/imagenet/resnet_v2_101/feature-vector/4",
  "resnet_v2_152": "https://tfhub.dev/google/imagenet/resnet_v2_152/feature-vector/4",
  "nasnet_large": "https://tfhub.dev/google/imagenet/nasnet_large/feature_vector/4",
  "nasnet_mobile": "https://tfhub.dev/google/imagenet/nasnet_mobile/feature_vector/4",
  "pnasnet_large": "https://tfhub.dev/google/imagenet/pnasnet_large/feature_vector/4",
  "mobilenet_v2_100_224": "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/4",
  "mobilenet_v2_130_224": "https://tfhub.dev/google/imagenet/mobilenet_v2_130_224/feature_vector/4",
  "mobilenet_v2_140_224": "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4",
  "mobilenet_v3_small_100_224": "https://tfhub.dev/google/imagenet/mobilenet_v3_small_100_224/feature_vector/5",
  "mobilenet_v3_small_075_224": "https://tfhub.dev/google/imagenet/mobilenet_v3_small_075_224/feature_vector/5",
  "mobilenet_v3_large_100_224": "https://tfhub.dev/google/imagenet/mobilenet_v3_large_100_224/feature_vector/5",
  "mobilenet_v3_large_075_224": "https://tfhub.dev/google/imagenet/mobilenet_v3_large_075_224/feature_vector/5",
}

model_image_size_map = {
  "efficientnetv2-s": 384,
  "efficientnetv2-m": 480,
  "efficientnetv2-l": 480,
  "efficientnetv2-b0": 224,
  "efficientnetv2-b1": 240,
  "efficientnetv2-b2": 260,
  "efficientnetv2-b3": 300,
  "efficientnetv2-s-21k": 384,
  "efficientnetv2-m-21k": 480,
  "efficientnetv2-l-21k": 480,
  "efficientnetv2-xl-21k": 512,
  "efficientnetv2-b0-21k": 224,
  "efficientnetv2-b1-21k": 240,
  "efficientnetv2-b2-21k": 260,
  "efficientnetv2-b3-21k": 300,
  "efficientnetv2-s-21k-ft1k": 384,
  "efficientnetv2-m-21k-ft1k": 480,
  "efficientnetv2-l-21k-ft1k": 480,
  "efficientnetv2-xl-21k-ft1k": 512,
  "efficientnetv2-b0-21k-ft1k": 224,
  "efficientnetv2-b1-21k-ft1k": 240,
  "efficientnetv2-b2-21k-ft1k": 260,
  "efficientnetv2-b3-21k-ft1k": 300, 
  "efficientnet_b0": 224,
  "efficientnet_b1": 240,
  "efficientnet_b2": 260,
  "efficientnet_b3": 300,
  "efficientnet_b4": 380,
  "efficientnet_b5": 456,
  "efficientnet_b6": 528,
  "efficientnet_b7": 600,
  "inception_v3": 299,
  "inception_resnet_v2": 299,
  "nasnet_large": 331,
  "pnasnet_large": 331,
}

model_handle = model_handle_map.get(model_name)
pixels = model_image_size_map.get(model_name, 224)

print(f"Selected model: {model_name} : {model_handle}")

IMAGE_SIZE = (pixels, pixels)
print(f"Input size {IMAGE_SIZE}")

BATCH_SIZE = 16#@param {type:"integer"}
# Out:
# Selected model: mobilenet_v2_140_224 : https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4
# Input size (224, 224)

# %% [markdown]
# ## 2. Preparing the UI Dataset
#
# The input is adjusted to the appropriate size according to the selected module. Dataset augmentation (i.e., random distortion of the image each time it is read) can particularly improve training when fine-tuning. To preparing the dataset, you need to aware the following:
#
# 1. Collect images of UI components from actual projects or screen captures. It is advisable to secure at least 50 images for each UI component, and the recommended quantity is more than 100 images.
# 2. If it is difficult to secure such a quantity of images, it is recommended to generate images using [figma-dummy-gen](https://github.com/dusskapark/figma-dummy-gen) and use them in conjunction with the images actually captured.
# 3. Put the prepared dataset in the `dataset` folder.

# %%
# Define the root path and the origin path
root_path = os.path.expanduser('./dataset/')
origin_path = root_path + 'TF_Image_classification/' # folder that contains the dummy images
screenshot_path = root_path + 'screenshot/' # folder that contains the real images that captured from the UI or Figma projects 
ui_path = root_path + 'ui/' # final UI dataset folder 

# Print the root path and the origin path
print('Origin path:', origin_path)
print('Screenshot path:', screenshot_path)
print('UI path:', ui_path)
# Out:
# Origin path: ./dataset/TF_Image_classification/
# Screenshot path: ./dataset/screenshot/
# UI path: ./dataset/ui/

# %% [markdown]
# ### 2-1. Checking the Original Dataset Structure
#
# The dataset is stored in the `origin_path`. The folder structure is as follows:
#
# ```
# TF_Image_classification
# |__ Accordion
#     |______ 100080576_f52e8ee070_n.jpg
#     |______ 14167534527_781ceb1b7a_n.jpg
#     |______ ...
# |__ App Bar
#     |______ 10043234166_e6dd915111_n.jpg
#     |______ 1426682852_e62169221f_m.jpg
#     |______ ...
# ```
#
# You can use the following code to identify the names of each folder and the number of files in each folder.

# %%
# Function to get the number of files in a directory
def get_num_files(path):
    return len([entry for entry in os.scandir(path) if entry.is_file()])

# Function to print the directory tree
def draw_folder_tree(path, level=0):
    expanded_path = os.path.expanduser(path)
    folders_files_count = {}

    for entry in os.scandir(expanded_path):
        if entry.is_dir():
            num_files = get_num_files(entry.path)
            folders_files_count[entry.name] = num_files

    sorted_folders_files_count = sorted(folders_files_count.items(), key=lambda item: item[0])

    for folder_name, files_count in sorted_folders_files_count:
        print(f"{'    '*level}|- {folder_name}/ ({files_count} files)")
        draw_folder_tree(os.path.join(path, folder_name), level+1)
        
# Draw the folder tree of the new directory
print('Train structure:')
draw_folder_tree(origin_path)
# Out:
# Train structure:
# |- Bottom app bars/ (32 files)
# |- Bottom sheets/ (16 files)
# |- Buttons/ (200 files)
# |- Cards/ (25 files)
# |- Carousel/ (57 files)
# |- Checkboxes/ (120 files)
# |- Chips/ (960 files)
# |- Date picker/ (33 files)
# |- Dialogs/ (28 files)
# |- FABs/ (256 files)
# |- Icon buttons/ (240 files)
# |- Menu/ (37 files)
# |- Menu List/ (2305 files)
# |- Navigation bars/ (25 files)
# |- Navigation drawer/ (129 files)
# |- Navigation rails/ (25 files)
# |- Progress indicators/ (40 files)
# |- Radio buttons/ (40 files)
# |- Search/ (128 files)
# |- Segmented buttons/ (65 files)
# |- Side sheets/ (32 files)
# |- Sliders/ (201 files)
# |- Switch/ (80 files)
# |- Tabs/ (41 files)
# |- Text Fields/ (960 files)
# |- Time picker/ (25 files)
# |- Tooltips/ (8 files)
# |- Top app bars/ (256 files)

# %% [markdown]
# ### 2-2. Adjusting Dataset Images
#
# The images in the dataset must be adjusted to match the input size of the model. For example, for MobileNetV3, the input size is 224x224x3, so the images in the dataset need to be adjusted to this size. The adjusted images are stored in the `ui_path` folder.

# %%
from PIL import Image

# Set the limit for the number of images per folder
LIMIT_IMAGES = 200  # Set to None for no limit

# Create the new directory if it doesn't exist
os.makedirs(ui_path, exist_ok=True)

# Get the list of all folders in the origin and screenshot paths
all_folders = set(os.listdir(origin_path) + os.listdir(screenshot_path))

# Loop through each folder in the list
for folder_name in all_folders:
    # Construct the full path to the origin and screenshot folders
    origin_folder_path = os.path.join(origin_path, folder_name)
    screenshot_folder_path = os.path.join(screenshot_path, folder_name)

    # Check if the origin and screenshot folders exist
    origin_exists = os.path.isdir(origin_folder_path)
    screenshot_exists = os.path.isdir(screenshot_folder_path)

    # If neither folder exists, skip this folder
    if not origin_exists and not screenshot_exists:
        print(f"Folder {folder_name} does not exist in either the origin or screenshot path. Please check the data.")
        continue

    # Get the list of files in the origin and screenshot folders
    origin_files = os.listdir(origin_folder_path) if origin_exists else []
    screenshot_files = os.listdir(screenshot_folder_path) if screenshot_exists else []

    # If there is a limit and the number of screenshot files is greater than the limit
    if LIMIT_IMAGES is not None and len(screenshot_files) > LIMIT_IMAGES:
        print(f"Folder {folder_name} has more than {LIMIT_IMAGES} images. Please check the data.")
        continue

    # Calculate the number of files to select from the origin folder
    num_files_to_select = min(len(origin_files), LIMIT_IMAGES-len(screenshot_files)) if LIMIT_IMAGES is not None else len(origin_files)

    # Randomly select files from the origin folder
    selected_origin_files = np.random.choice(origin_files, size=num_files_to_select, replace=False).tolist() if num_files_to_select > 0 else []

    # Combine the screenshot and selected origin files
    combined_files = screenshot_files + selected_origin_files

    # Shuffle the combined files
    np.random.shuffle(combined_files)

    # Create the new folder if it doesn't exist
    new_folder_path = os.path.join(ui_path, folder_name)
    os.makedirs(new_folder_path, exist_ok=True)
    
    # Loop through each file in the combined files
    for filename in combined_files:
        # Only process .png files
        if filename.endswith('.png'):
            # Check if the file is from the screenshot or origin folder
            if filename in screenshot_files:
                folder_path = screenshot_folder_path
            else:
                folder_path = origin_folder_path

            # Construct the full path to the file
            file_path = os.path.join(folder_path, filename)
            
            # Open the image file
            img = Image.open(file_path).convert("RGBA")
            
            # Get the width and height of the image
            width, height = img.size
            
            # Create a new square image with alpha channel
            new_image = Image.new('RGBA', (max(width, height), max(width, height)))
            
            # Paste the original image into the center of the new image
            new_image.paste(img, (int((new_image.width - img.width) / 2), int((new_image.height - img.height) / 2)))
            
            # Create a white background image
            bg = Image.new('RGBA', new_image.size, (255, 255, 255, 255))  # RGBA mode
            
            # Combine the new image with the white background
            final_image = Image.alpha_composite(bg, new_image)
            
            # Resize the final image to the target size
            final_image = final_image.resize([224, 224], Image.LANCZOS)
            
            # Construct the new file path
            new_file_path = os.path.join(new_folder_path, filename)
            
            # Save the new image as PNG
            final_image.save(new_file_path, format='PNG')
            
            # Print the result
            print(f"Saved new image at {new_file_path}")
# Out:
# Folder Switch has more than 200 images. Please check the data.
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 12 - 28.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 12 - 12.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 15 - 15.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 4 - 214.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 3 - 213.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 2 - 18.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 3 - 03.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 5 - 199.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 3 - 197.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 14 - 14.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 2 - 02.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 10 - 220.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 7 - 07.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 15 - 225.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 9 - 25.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 12 - 206.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 11 - 205.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 15 - 31.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 10 - 204.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 16 - 32.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 8 - 202.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 14 - 224.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 6 - 22.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 7 - 23.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 13 - 29.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 13 - 223.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 9 - 203.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 11 - 221.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 4 - 04.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 6 - 06.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 13 - 13.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 8 - 218.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 1 - 195.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 15 - 209.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 16 - 226.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 5 - 21.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 13 - 207.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 6 - 216.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 4 - 20.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 5 - 05.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 10 - 10.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 1 - 01.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 1 - 211.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 7 - 201.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 3 - 19.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 1 - 17.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 2 - 212.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 8 - 24.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 10 - 26.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 16 - 210.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 11 - 27.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 11 - 11.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 14 - 30.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 14 - 208.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 7 - 217.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 16 - 16.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 4 - 198.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 9 - 09.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 12 - 222.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button - 8 - 08.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 9 - 219.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 5 - 215.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 2 - 196.png
# Saved new image at ./dataset/ui/Segmented buttons/Segmented button-dark - 6 - 200.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 6 - 12.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 1 - 01.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 1 - 109.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 6 - 114.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 2 - 116.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 4 - 118.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 2 - 110.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 5 - 11.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 6 - 06.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 1 - 115.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 5 - 119.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 2 - 02.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 4 - 112.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 6 - 120.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 5 - 113.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 2 - 08.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 4 - 04.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 3 - 09.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 3 - 03.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 3 - 111.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail-dark - 3 - 117.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 1 - 07.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 5 - 05.png
# Saved new image at ./dataset/ui/Navigation rails/Navigation Rail - 4 - 10.png
# Folder Icon buttons has more than 200 images. Please check the data.
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 27 - 555.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 30 - 414.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 47 - 335.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 2 - 290.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 21 - 453.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 21 - 597.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 2 - 578.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 74 - 362.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 28 - 940.png
# Saved new image at ./dataset/ui/Chips/Input chip - 6 - 54.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 25 - 793.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 42 - 666.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 13 - 157.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 53 - 341.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 54 - 342.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 80 - 848.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 4 - 868.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 17 - 881.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 2 - 434.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 22 - 790.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 96 - 864.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 20 - 404.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 6 - 150.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 44 - 668.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 15 - 495.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 24 - 600.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 6 - 534.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 67 - 739.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 14 - 542.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 88 - 376.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 6 - 438.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 76 - 364.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 34 - 802.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 13 - 205.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 12 - 684.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 47 - 143.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 5 - 293.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 46 - 430.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 67 - 259.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 27 - 699.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 48 - 720.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 33 - 129.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 3 - 195.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 80 - 752.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 18 - 930.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 43 - 667.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 3 - 915.png
# Saved new image at ./dataset/ui/Chips/Input chip - 11 - 59.png
# Saved new image at ./dataset/ui/Chips/Input chip - 18 - 66.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 59 - 731.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 30 - 702.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 88 - 760.png
# Saved new image at ./dataset/ui/Chips/Input chip - 19 - 67.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 28 - 652.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 37 - 805.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 16 - 448.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 1 - 289.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 14 - 302.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 33 - 465.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 11 - 683.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 37 - 469.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 25 - 601.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 31 - 415.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 16 - 160.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 28 - 316.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 55 - 823.png
# Saved new image at ./dataset/ui/Chips/Input chip - 29 - 29.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 47 - 959.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 91 - 859.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 1 - 529.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 46 - 958.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 39 - 711.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 45 - 669.png
# Saved new image at ./dataset/ui/Chips/Input chip - 39 - 39.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 15 - 207.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 26 - 314.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 34 - 130.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 38 - 662.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 4 - 292.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 70 - 742.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 69 - 837.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 8 - 440.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 40 - 472.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 7 - 295.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 28 - 172.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 24 - 888.png
# Saved new image at ./dataset/ui/Chips/Input chip - 45 - 45.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 5 - 773.png
# Saved new image at ./dataset/ui/Chips/Input chip - 47 - 47.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 12 - 588.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 92 - 764.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 40 - 568.png
# Saved new image at ./dataset/ui/Chips/Input chip - 3 - 03.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 13 - 445.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 96 - 288.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 6 - 678.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 9 - 873.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 7 - 919.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 71 - 743.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 58 - 826.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 22 - 310.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 4 - 148.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 12 - 924.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 5 - 389.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 87 - 375.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 95 - 287.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 28 - 700.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 9 - 777.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 39 - 663.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 23 - 695.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 7 - 439.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 20 - 548.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 39 - 135.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 70 - 838.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 22 - 646.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 53 - 245.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 18 - 402.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 87 - 279.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 27 - 459.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 28 - 412.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 57 - 729.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 20 - 692.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 96 - 384.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 75 - 267.png
# Saved new image at ./dataset/ui/Chips/Input chip - 12 - 60.png
# Saved new image at ./dataset/ui/Chips/Input chip - 26 - 74.png
# Saved new image at ./dataset/ui/Chips/Input chip - 21 - 69.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 59 - 827.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 45 - 909.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 3 - 627.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 48 - 336.png
# Saved new image at ./dataset/ui/Chips/Input chip - 33 - 33.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 41 - 425.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 44 - 956.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 33 - 225.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 35 - 707.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 73 - 361.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 10 - 394.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 38 - 710.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 14 - 110.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 13 - 541.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 47 - 527.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 42 - 810.png
# Saved new image at ./dataset/ui/Chips/Input chip - 25 - 73.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 6 - 774.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 26 - 458.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 22 - 406.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 65 - 257.png
# Saved new image at ./dataset/ui/Chips/Input chip - 36 - 36.png
# Saved new image at ./dataset/ui/Chips/Input chip - 34 - 34.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 2 - 386.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 20 - 452.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 14 - 926.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 58 - 346.png
# Saved new image at ./dataset/ui/Chips/Input chip - 31 - 79.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 20 - 308.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 63 - 351.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 88 - 280.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 13 - 301.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 46 - 574.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 46 - 670.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 44 - 620.png
# Saved new image at ./dataset/ui/Chips/Input chip - 5 - 53.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 34 - 610.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 47 - 911.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 86 - 278.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 36 - 516.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 28 - 508.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 61 - 253.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 35 - 227.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 89 - 857.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 27 - 507.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 88 - 856.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 3 - 675.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 54 - 246.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 4 - 436.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 40 - 664.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 29 - 317.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 17 - 593.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 75 - 843.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 21 - 693.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 13 - 493.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 24 - 120.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 24 - 552.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 7 - 151.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 58 - 730.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 69 - 261.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 48 - 576.png
# Saved new image at ./dataset/ui/Chips/Assistive chip - 15 - 111.png
# Saved new image at ./dataset/ui/Chips/Input chip - 5 - 05.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 9 - 393.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 44 - 332.png
# Saved new image at ./dataset/ui/Chips/Assistive chip-dark - 1 - 625.png
# Saved new image at ./dataset/ui/Chips/Filter chip - 24 - 216.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 45 - 717.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 10 - 778.png
# Saved new image at ./dataset/ui/Chips/Input chip-dark - 25 - 553.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip - 47 - 431.png
# Saved new image at ./dataset/ui/Chips/Suggestion chip-dark - 17 - 929.png
# Saved new image at ./dataset/ui/Chips/Filter chip-dark - 55 - 727.png
# Saved new image at ./dataset/ui/Cards/wf_198_060.png
# Saved new image at ./dataset/ui/Cards/wf_198_055.png
# Saved new image at ./dataset/ui/Cards/Horizontal card-dark - 2 - 53.png
# Saved new image at ./dataset/ui/Cards/Horizontal card-dark - 1 - 52.png
# Saved new image at ./dataset/ui/Cards/Horizontal card-dark - 2 - 50.png
# Saved new image at ./dataset/ui/Cards/29785_036.png
# Saved new image at ./dataset/ui/Cards/Horizontal card - 1 - 10.png
# Saved new image at ./dataset/ui/Cards/65947_016.png
# Saved new image at ./dataset/ui/Cards/uplabs_192_017.png
# Saved new image at ./dataset/ui/Cards/wf_179_023.png
# Saved new image at ./dataset/ui/Cards/Stacked card - 3 - 06.png
# Saved new image at ./dataset/ui/Cards/27990_007.png
# Saved new image at ./dataset/ui/Cards/20610_017.png
# Saved new image at ./dataset/ui/Cards/wf_179_026.png
# Saved new image at ./dataset/ui/Cards/36779_008.png
# Saved new image at ./dataset/ui/Cards/uplabs_421_008.png
# Saved new image at ./dataset/ui/Cards/29819_019.png
# Saved new image at ./dataset/ui/Cards/wf_200_034.png
# Saved new image at ./dataset/ui/Cards/wf_180_036.png
# Saved new image at ./dataset/ui/Cards/wf_128_016.png
# Saved new image at ./dataset/ui/Cards/48432_016.png
# Saved new image at ./dataset/ui/Cards/wf_21_047.png
# Saved new image at ./dataset/ui/Cards/wf_186_050.png
# Saved new image at ./dataset/ui/Cards/29791_028.png
# Saved new image at ./dataset/ui/Cards/Stacked card-dark - 2 - 47.png
# Saved new image at ./dataset/ui/Cards/wf_8_017.png
# Saved new image at ./dataset/ui/Cards/Horizontal card-dark - 3 - 54.png
# Saved new image at ./dataset/ui/Cards/wf_200_032.png
# Saved new image at ./dataset/ui/Cards/54591_011.png
# Saved new image at ./dataset/ui/Cards/48432_015.png
# Saved new image at ./dataset/ui/Cards/41837_026.png
# Saved new image at ./dataset/ui/Cards/wf_196_053.png
# Saved new image at ./dataset/ui/Cards/wf_101_016.png
# Saved new image at ./dataset/ui/Cards/48432_014.png
# Saved new image at ./dataset/ui/Cards/54589_006.png
# Saved new image at ./dataset/ui/Cards/wf_21_042.png
# Saved new image at ./dataset/ui/Cards/29789_023.png
# Saved new image at ./dataset/ui/Cards/wf_156_019.png
# Saved new image at ./dataset/ui/Cards/wf_179_024.png
# Saved new image at ./dataset/ui/Cards/Horizontal card - 2 - 11.png
# Saved new image at ./dataset/ui/Cards/wf_128_018.png
# Saved new image at ./dataset/ui/Cards/48572_012.png
# Saved new image at ./dataset/ui/Cards/wf_165_018.png
# Saved new image at ./dataset/ui/Cards/29789_024.png
# Saved new image at ./dataset/ui/Cards/17226_016.png
# Saved new image at ./dataset/ui/Cards/29820_023.png
# Saved new image at ./dataset/ui/Cards/wf_101_017.png
# Saved new image at ./dataset/ui/Cards/Stacked card - 2 - 05.png
# Saved new image at ./dataset/ui/Cards/27238_025.png
# Saved new image at ./dataset/ui/Cards/53737_021.png
# Saved new image at ./dataset/ui/Cards/Horizontal card - 2 - 08.png
# Saved new image at ./dataset/ui/Cards/4138_008.png
# Saved new image at ./dataset/ui/Cards/34140_029.png
# Saved new image at ./dataset/ui/Cards/29819_020.png
# Saved new image at ./dataset/ui/Cards/44522_037.png
# Saved new image at ./dataset/ui/Cards/56023_006.png
# Saved new image at ./dataset/ui/Cards/wf_8_016.png
# Saved new image at ./dataset/ui/Cards/29785_031.png
# Saved new image at ./dataset/ui/Cards/wf_198_059.png
# Saved new image at ./dataset/ui/Cards/45870_008.png
# Saved new image at ./dataset/ui/Cards/Horizontal card - 1 - 07.png
# Saved new image at ./dataset/ui/Cards/wf_21_044.png
# Saved new image at ./dataset/ui/Cards/wf_200_033.png
# Saved new image at ./dataset/ui/Cards/wf_200_031.png
# Saved new image at ./dataset/ui/Cards/Stacked card - 3 - 03.png
# Saved new image at ./dataset/ui/Cards/wf_198_058.png
# Saved new image at ./dataset/ui/Cards/uplabs_48_008.png
# Saved new image at ./dataset/ui/Cards/uplabs_151_007.png
# Saved new image at ./dataset/ui/Cards/wf_179_022.png
# Saved new image at ./dataset/ui/Cards/66861_013.png
# Saved new image at ./dataset/ui/Cards/29785_029.png
# Saved new image at ./dataset/ui/Cards/23806_013.png
# Saved new image at ./dataset/ui/Cards/34140_031.png
# Saved new image at ./dataset/ui/Cards/56556_011.png
# Saved new image at ./dataset/ui/Cards/wf_196_056.png
# Saved new image at ./dataset/ui/Cards/uplabs_28_007.png
# Saved new image at ./dataset/ui/Cards/wf_101_015.png
# Saved new image at ./dataset/ui/Cards/Stacked card-dark - 1 - 43.png
# Saved new image at ./dataset/ui/Cards/Stacked card-dark - 3 - 48.png
# Saved new image at ./dataset/ui/Cards/48572_014.png
# Saved new image at ./dataset/ui/Cards/uplabs_450_007.png
# Saved new image at ./dataset/ui/Cards/44522_032.png
# Saved new image at ./dataset/ui/Cards/wf_21_039.png
# Saved new image at ./dataset/ui/Cards/uplabs_132_007.png
# Saved new image at ./dataset/ui/Cards/29791_026.png
# Saved new image at ./dataset/ui/Cards/48432_013.png
# Saved new image at ./dataset/ui/Cards/Horizontal card-dark - 3 - 51.png
# Saved new image at ./dataset/ui/Cards/20610_016.png
# Saved new image at ./dataset/ui/Cards/29820_024.png
# Saved new image at ./dataset/ui/Cards/Stacked card - 1 - 01.png
# Saved new image at ./dataset/ui/Cards/41837_027.png
# Saved new image at ./dataset/ui/Cards/Stacked card-dark - 2 - 44.png
# Saved new image at ./dataset/ui/Cards/2206_015.png
# Saved new image at ./dataset/ui/Cards/wf_198_057.png
# Saved new image at ./dataset/ui/Cards/wf_156_015.png
# Saved new image at ./dataset/ui/Cards/wf_196_054.png
# Saved new image at ./dataset/ui/Cards/40697_010.png
# Saved new image at ./dataset/ui/Cards/uplabs_181_014.png
# Saved new image at ./dataset/ui/Cards/41837_021.png
# Saved new image at ./dataset/ui/Cards/41837_025.png
# Saved new image at ./dataset/ui/Cards/wf_62_022.png
# Saved new image at ./dataset/ui/Cards/wf_21_045.png
# Saved new image at ./dataset/ui/Cards/44522_034.png
# Saved new image at ./dataset/ui/Cards/uplabs_105_007.png
# Saved new image at ./dataset/ui/Cards/uplabs_181_015.png
# Saved new image at ./dataset/ui/Cards/wf_21_041.png
# Saved new image at ./dataset/ui/Cards/wf_166_034.png
# Saved new image at ./dataset/ui/Cards/wf_196_055.png
# Saved new image at ./dataset/ui/Cards/69270_019.png
# Saved new image at ./dataset/ui/Cards/29785_028.png
# Saved new image at ./dataset/ui/Cards/wf_180_034.png
# Saved new image at ./dataset/ui/Cards/wf_166_032.png
# Saved new image at ./dataset/ui/Cards/wf_21_046.png
# Saved new image at ./dataset/ui/Cards/uplabs_186_008.png
# Saved new image at ./dataset/ui/Cards/27238_024.png
# Saved new image at ./dataset/ui/Cards/29785_035.png
# Saved new image at ./dataset/ui/Cards/34140_030.png
# Saved new image at ./dataset/ui/Cards/wf_179_025.png
# Saved new image at ./dataset/ui/Cards/53737_020.png
# Saved new image at ./dataset/ui/Cards/20610_015.png
# Saved new image at ./dataset/ui/Cards/Horizontal card - 3 - 09.png
# Saved new image at ./dataset/ui/Cards/uplabs_465_013.png
# Saved new image at ./dataset/ui/Cards/56024_007.png
# Saved new image at ./dataset/ui/Cards/44522_028.png
# Saved new image at ./dataset/ui/Cards/wf_180_035.png
# Saved new image at ./dataset/ui/Cards/Stacked card - 1 - 04.png
# Saved new image at ./dataset/ui/Cards/wf_21_043.png
# Saved new image at ./dataset/ui/Cards/wf_21_040.png
# Saved new image at ./dataset/ui/Cards/wf_186_046.png
# Saved new image at ./dataset/ui/Cards/wf_62_018.png
# Saved new image at ./dataset/ui/Cards/wf_186_047.png
# Saved new image at ./dataset/ui/Cards/44522_033.png
# Saved new image at ./dataset/ui/Cards/wf_180_040.png
# Saved new image at ./dataset/ui/Cards/Horizontal card - 3 - 12.png
# Saved new image at ./dataset/ui/Cards/27238_023.png
# Saved new image at ./dataset/ui/Cards/wf_180_033.png
# Saved new image at ./dataset/ui/Cards/wf_198_053.png
# Saved new image at ./dataset/ui/Cards/wf_186_044.png
# Saved new image at ./dataset/ui/Cards/wf_180_039.png
# Saved new image at ./dataset/ui/Cards/wf_200_030.png
# Saved new image at ./dataset/ui/Cards/917_011.png
# Saved new image at ./dataset/ui/Cards/uplabs_589_010.png
# Saved new image at ./dataset/ui/Cards/48572_013.png
# Saved new image at ./dataset/ui/Cards/45641_043.png
# Saved new image at ./dataset/ui/Cards/29791_027.png
# Saved new image at ./dataset/ui/Cards/wf_196_052.png
# Saved new image at ./dataset/ui/Cards/wf_128_017.png
# Saved new image at ./dataset/ui/Cards/29777_026.png
# Saved new image at ./dataset/ui/Cards/wf_186_048.png
# Saved new image at ./dataset/ui/Cards/wf_8_018.png
# Saved new image at ./dataset/ui/Cards/wf_147_008.png
# Saved new image at ./dataset/ui/Cards/wf_186_049.png
# Saved new image at ./dataset/ui/Cards/28924_023.png
# Saved new image at ./dataset/ui/Cards/uplabs_69_007.png
# Saved new image at ./dataset/ui/Cards/29791_024.png
# Saved new image at ./dataset/ui/Cards/29785_034.png
# Saved new image at ./dataset/ui/Cards/29777_025.png
# Saved new image at ./dataset/ui/Cards/wf_62_023.png
# Saved new image at ./dataset/ui/Cards/27239_021.png
# Saved new image at ./dataset/ui/Cards/wf_62_021.png
# Saved new image at ./dataset/ui/Cards/29785_030.png
# Saved new image at ./dataset/ui/Cards/wf_198_056.png
# Saved new image at ./dataset/ui/Cards/uplabs_255_007.png
# Saved new image at ./dataset/ui/Cards/wf_196_051.png
# Saved new image at ./dataset/ui/Cards/Stacked card-dark - 1 - 46.png
# Saved new image at ./dataset/ui/Cards/wf_98_007.png
# Saved new image at ./dataset/ui/Cards/wf_62_020.png
# Saved new image at ./dataset/ui/Cards/27990_008.png
# Saved new image at ./dataset/ui/Cards/wf_156_016.png
# Saved new image at ./dataset/ui/Cards/20610_018.png
# Saved new image at ./dataset/ui/Cards/wf_198_054.png
# Saved new image at ./dataset/ui/Cards/uplabs_373_008.png
# Saved new image at ./dataset/ui/Cards/Stacked card - 2 - 02.png
# Saved new image at ./dataset/ui/Cards/wf_156_018.png
# Saved new image at ./dataset/ui/Cards/44522_035.png
# Saved new image at ./dataset/ui/Cards/29789_022.png
# Saved new image at ./dataset/ui/Cards/29785_032.png
# Saved new image at ./dataset/ui/Cards/wf_156_017.png
# Saved new image at ./dataset/ui/Cards/wf_166_033.png
# Saved new image at ./dataset/ui/Cards/44522_036.png
# Saved new image at ./dataset/ui/Cards/wf_186_045.png
# Saved new image at ./dataset/ui/Cards/20610_019.png
# Saved new image at ./dataset/ui/Cards/uplabs_684_015.png
# Saved new image at ./dataset/ui/Cards/29791_025.png
# Saved new image at ./dataset/ui/Cards/Stacked card-dark - 3 - 45.png
# Saved new image at ./dataset/ui/Cards/29777_027.png
# Saved new image at ./dataset/ui/Cards/29785_033.png
# Saved new image at ./dataset/ui/Cards/17223_027.png
# Saved new image at ./dataset/ui/Cards/Horizontal card-dark - 1 - 49.png
# Saved new image at ./dataset/ui/Cards/57270_010.png
# Saved new image at ./dataset/ui/Cards/wf_62_019.png
# Saved new image at ./dataset/ui/Cards/uplabs_570_017.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 7 - 39.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 4 - 44.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 2 - 18.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 2 - 26.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 4 - 36.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 1 - 33.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 8 - 32.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 5 - 37.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 1 - 17.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 5 - 21.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 2 - 34.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 8 - 40.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 5 - 29.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 6 - 38.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 4 - 20.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 7 - 47.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 6 - 30.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 4 - 28.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 3 - 19.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 7 - 23.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 2 - 42.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 1 - 25.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 1 - 41.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 6 - 22.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 8 - 24.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 8 - 48.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 5 - 45.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 6 - 46.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 3 - 35.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 3 - 27.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar - 7 - 31.png
# Saved new image at ./dataset/ui/Bottom app bars/Bottom app bar-dark - 3 - 43.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 6 - 20.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 5 - 13.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 3 - 791.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 4 - 792.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 2 - 796.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 1 - 795.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 1 - 789.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 5 - 19.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 2 - 790.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 6 - 794.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 5 - 799.png
# Saved new image at ./dataset/ui/Menu/Menu - 4 - 10.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 6 - 14.png
# Saved new image at ./dataset/ui/Menu/Menu - 3 - 09.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 4 - 12.png
# Saved new image at ./dataset/ui/Menu/Menu - 1 - 01.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 4 - 798.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 2 - 10.png
# Saved new image at ./dataset/ui/Menu/Menu - 1 - 07.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 3 - 797.png
# Saved new image at ./dataset/ui/Menu/Menu - 6 - 12.png
# Saved new image at ./dataset/ui/Menu/Menu - 3 - 03.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 6 - 800.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 2 - 16.png
# Saved new image at ./dataset/ui/Menu/Menu - 6 - 06.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 3 - 11.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 3 - 17.png
# Saved new image at ./dataset/ui/Menu/Menu - 2 - 02.png
# Saved new image at ./dataset/ui/Menu/Menu - 2 - 08.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 5 - 793.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 4 - 18.png
# Saved new image at ./dataset/ui/Menu/Menu - 4 - 04.png
# Saved new image at ./dataset/ui/Menu/Menu - 5 - 11.png
# Saved new image at ./dataset/ui/Menu/Menu - 5 - 05.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 1 - 15.png
# Saved new image at ./dataset/ui/Menu/Menu-dark - 1 - 09.png
# Saved new image at ./dataset/ui/Checkboxes/676_019.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 19 - 19.png
# Saved new image at ./dataset/ui/Checkboxes/1211_003.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 23 - 23.png
# Saved new image at ./dataset/ui/Checkboxes/677_007.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 4 - 34.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 3 - 33.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 30 - 120.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 25 - 55.png
# Saved new image at ./dataset/ui/Checkboxes/676_007.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 18 - 18.png
# Saved new image at ./dataset/ui/Checkboxes/677_001.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 26 - 56.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 17 - 107.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 5 - 95.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 19 - 49.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 16 - 46.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 11 - 71.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 25 - 115.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 28 - 88.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 10 - 40.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 2 - 62.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 3 - 93.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 18 - 78.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 19 - 79.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_629_014.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 20 - 110.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 5 - 65.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 6 - 96.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 14 - 74.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 25 - 85.png
# Saved new image at ./dataset/ui/Checkboxes/677_013.png
# Saved new image at ./dataset/ui/Checkboxes/228_018.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 20 - 50.png
# Saved new image at ./dataset/ui/Checkboxes/676_005.png
# Saved new image at ./dataset/ui/Checkboxes/IMG_3614_009.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 22 - 82.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 21 - 21.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 17 - 17.png
# Saved new image at ./dataset/ui/Checkboxes/IMG_1630_007.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 21 - 81.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 1 - 01.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 17 - 47.png
# Saved new image at ./dataset/ui/Checkboxes/1007_004.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 29 - 29.png
# Saved new image at ./dataset/ui/Checkboxes/228_011.png
# Saved new image at ./dataset/ui/Checkboxes/887_010.png
# Saved new image at ./dataset/ui/Checkboxes/1211_009.png
# Saved new image at ./dataset/ui/Checkboxes/325_001.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_644_015.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 14 - 104.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 24 - 84.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 20 - 20.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 23 - 53.png
# Saved new image at ./dataset/ui/Checkboxes/IMG_3768_010.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_583_013.png
# Saved new image at ./dataset/ui/Checkboxes/1211_005.png
# Saved new image at ./dataset/ui/Checkboxes/676_017.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 16 - 76.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_615_013.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 8 - 98.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 10 - 70.png
# Saved new image at ./dataset/ui/Checkboxes/228_005.png
# Saved new image at ./dataset/ui/Checkboxes/676_009.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 21 - 111.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_543_010.png
# Saved new image at ./dataset/ui/Checkboxes/676_011.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 15 - 75.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 23 - 83.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_618_008.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 26 - 26.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 6 - 36.png
# Saved new image at ./dataset/ui/Checkboxes/1211_007.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 24 - 54.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 1 - 61.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 22 - 22.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 9 - 99.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 27 - 27.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 29 - 89.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_599_013.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 28 - 28.png
# Saved new image at ./dataset/ui/Checkboxes/676_021.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 13 - 73.png
# Saved new image at ./dataset/ui/Checkboxes/IMG_1536_013.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 15 - 15.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 21 - 51.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 7 - 67.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 18 - 108.png
# Saved new image at ./dataset/ui/Checkboxes/1202_015.png
# Saved new image at ./dataset/ui/Checkboxes/28_013.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 25 - 25.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 10 - 10.png
# Saved new image at ./dataset/ui/Checkboxes/549_003.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_821_008.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_722_007.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 6 - 06.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 7 - 37.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 8 - 38.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 4 - 64.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 9 - 09.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 15 - 45.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 5 - 05.png
# Saved new image at ./dataset/ui/Checkboxes/wf_175_018.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 11 - 101.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 28 - 58.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 12 - 72.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 7 - 97.png
# Saved new image at ./dataset/ui/Checkboxes/100_012.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_792_009.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 6 - 66.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 29 - 119.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 22 - 112.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 17 - 77.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 4 - 94.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_734_007.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 9 - 39.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 30 - 30.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 29 - 59.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 19 - 109.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_596_008.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_756_015.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 3 - 63.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 11 - 11.png
# Saved new image at ./dataset/ui/Checkboxes/1211_017.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 16 - 16.png
# Saved new image at ./dataset/ui/Checkboxes/887_005.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 26 - 116.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 23 - 113.png
# Saved new image at ./dataset/ui/Checkboxes/676_013.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 27 - 117.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_803_009.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 4 - 04.png
# Saved new image at ./dataset/ui/Checkboxes/549_016.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 9 - 69.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 12 - 12.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 5 - 35.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 20 - 80.png
# Saved new image at ./dataset/ui/Checkboxes/676_023.png
# Saved new image at ./dataset/ui/Checkboxes/228_014.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 22 - 52.png
# Saved new image at ./dataset/ui/Checkboxes/wf_175_016.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 18 - 48.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 24 - 114.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 15 - 105.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 3 - 03.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 8 - 68.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 12 - 102.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 30 - 90.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 7 - 07.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 11 - 41.png
# Saved new image at ./dataset/ui/Checkboxes/1007_001.png
# Saved new image at ./dataset/ui/Checkboxes/549_011.png
# Saved new image at ./dataset/ui/Checkboxes/676_003.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 27 - 87.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 27 - 57.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 14 - 44.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 26 - 86.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_557_005.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 13 - 13.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 13 - 103.png
# Saved new image at ./dataset/ui/Checkboxes/1211_015.png
# Saved new image at ./dataset/ui/Checkboxes/676_015.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 12 - 42.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 10 - 100.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_746_013.png
# Saved new image at ./dataset/ui/Checkboxes/887_013.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 24 - 24.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_786_010.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 1 - 31.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 16 - 106.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 30 - 60.png
# Saved new image at ./dataset/ui/Checkboxes/uplabs_776_012.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 8 - 08.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 1 - 91.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 2 - 32.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes-dark - 28 - 118.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 13 - 43.png
# Saved new image at ./dataset/ui/Checkboxes/Checkboxes - 14 - 14.png
# ...
# Saved new image at ./dataset/ui/Sliders/Slider - 21 - 71.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 37 - 211.png
# Saved new image at ./dataset/ui/Sliders/Slider - 49 - 49.png
# Saved new image at ./dataset/ui/Sliders/Slider - 25 - 25.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 27 - 201.png
# Saved new image at ./dataset/ui/Sliders/Slider - 46 - 46.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 12 - 136.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 26 - 200.png
# Saved new image at ./dataset/ui/Sliders/Slider - 22 - 72.png
# Saved new image at ./dataset/ui/Sliders/Slider - 13 - 63.png
# Saved new image at ./dataset/ui/Sliders/Slider - 25 - 75.png
# Saved new image at ./dataset/ui/Sliders/Slider - 3 - 03.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 5 - 129.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 28 - 202.png
# Saved new image at ./dataset/ui/Sliders/Slider - 22 - 22.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 19 - 143.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 27 - 151.png
# Saved new image at ./dataset/ui/Sliders/Slider - 32 - 32.png
# Saved new image at ./dataset/ui/Sliders/Slider - 40 - 40.png
# Saved new image at ./dataset/ui/Sliders/Slider - 5 - 55.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 22 - 146.png
# Saved new image at ./dataset/ui/Sliders/Slider - 42 - 92.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 32 - 156.png
# Saved new image at ./dataset/ui/Sliders/Slider - 10 - 10.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 40 - 214.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 9 - 183.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 2 - 126.png
# Saved new image at ./dataset/ui/Sliders/Slider - 45 - 45.png
# Saved new image at ./dataset/ui/Sliders/Slider - 50 - 100.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 49 - 173.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 25 - 199.png
# Saved new image at ./dataset/ui/Sliders/Slider - 15 - 65.png
# Saved new image at ./dataset/ui/Sliders/Slider - 28 - 78.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 11 - 135.png
# Saved new image at ./dataset/ui/Sliders/Slider - 23 - 23.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 30 - 154.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 24 - 198.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 6 - 180.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 9 - 133.png
# Saved new image at ./dataset/ui/Sliders/Slider - 31 - 31.png
# Saved new image at ./dataset/ui/Sliders/Slider - 37 - 87.png
# Saved new image at ./dataset/ui/Sliders/Slider - 30 - 80.png
# Saved new image at ./dataset/ui/Sliders/Slider - 44 - 94.png
# Saved new image at ./dataset/ui/Sliders/Slider - 47 - 47.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 50 - 174.png
# Saved new image at ./dataset/ui/Sliders/Slider - 17 - 67.png
# Saved new image at ./dataset/ui/Sliders/Slider - 4 - 04.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 21 - 145.png
# Saved new image at ./dataset/ui/Sliders/Slider - 33 - 83.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 4 - 178.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 48 - 172.png
# Saved new image at ./dataset/ui/Sliders/Slider - 40 - 90.png
# Saved new image at ./dataset/ui/Sliders/Slider - 8 - 08.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 22 - 196.png
# Saved new image at ./dataset/ui/Sliders/Slider - 19 - 69.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 33 - 157.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 3 - 177.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 26 - 150.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 25 - 149.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 16 - 140.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 48 - 222.png
# Saved new image at ./dataset/ui/Sliders/Slider - 34 - 34.png
# Saved new image at ./dataset/ui/Sliders/Slider - 31 - 81.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 17 - 191.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 34 - 208.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 7 - 181.png
# Saved new image at ./dataset/ui/Sliders/Slider - 11 - 11.png
# Saved new image at ./dataset/ui/Sliders/Slider - 18 - 18.png
# Saved new image at ./dataset/ui/Sliders/Slider - 28 - 28.png
# Saved new image at ./dataset/ui/Sliders/Slider - 17 - 17.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 6 - 130.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 10 - 184.png
# Saved new image at ./dataset/ui/Sliders/Slider - 41 - 41.png
# Saved new image at ./dataset/ui/Sliders/Slider - 37 - 37.png
# Saved new image at ./dataset/ui/Sliders/Slider - 12 - 62.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 43 - 167.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 18 - 192.png
# Saved new image at ./dataset/ui/Sliders/Slider - 8 - 58.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 31 - 205.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 8 - 182.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 29 - 153.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 10 - 134.png
# Saved new image at ./dataset/ui/Sliders/Slider - 20 - 70.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 41 - 215.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 8 - 132.png
# Saved new image at ./dataset/ui/Sliders/Slider - 1 - 01.png
# Saved new image at ./dataset/ui/Sliders/Slider - 27 - 77.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 20 - 194.png
# Saved new image at ./dataset/ui/Sliders/Slider - 7 - 57.png
# Saved new image at ./dataset/ui/Sliders/Slider - 9 - 09.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 12 - 186.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 21 - 195.png
# Saved new image at ./dataset/ui/Sliders/Slider - 43 - 93.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 32 - 206.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 23 - 147.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 42 - 166.png
# Saved new image at ./dataset/ui/Sliders/Slider - 2 - 02.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 38 - 212.png
# Saved new image at ./dataset/ui/Sliders/Slider - 4 - 54.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 39 - 163.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 20 - 144.png
# Saved new image at ./dataset/ui/Sliders/Slider - 26 - 26.png
# Saved new image at ./dataset/ui/Sliders/Slider - 16 - 16.png
# Saved new image at ./dataset/ui/Sliders/Slider - 18 - 68.png
# Saved new image at ./dataset/ui/Sliders/Slider - 7 - 07.png
# Saved new image at ./dataset/ui/Sliders/Slider - 5 - 05.png
# Saved new image at ./dataset/ui/Sliders/Slider - 14 - 64.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 50 - 224.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 31 - 155.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 44 - 168.png
# Saved new image at ./dataset/ui/Sliders/Slider - 49 - 99.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 17 - 141.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 15 - 139.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 1 - 125.png
# Saved new image at ./dataset/ui/Sliders/Slider-dark - 13 - 187.png
# Folder Dialogs has more than 200 images. Please check the data.
# Saved new image at ./dataset/ui/Navigation bars/wf_177_002.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 6 - 06.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 2 - 110.png
# Saved new image at ./dataset/ui/Navigation bars/wf_4_002.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 6 - 120.png
# Saved new image at ./dataset/ui/Navigation bars/1215_033.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 1 - 115.png
# Saved new image at ./dataset/ui/Navigation bars/10244_035.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 2 - 08.png
# Saved new image at ./dataset/ui/Navigation bars/1221_029.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 1 - 109.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 4 - 112.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 5 - 113.png
# Saved new image at ./dataset/ui/Navigation bars/12928_024.png
# Saved new image at ./dataset/ui/Navigation bars/12922_025.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 2 - 02.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 4 - 10.png
# Saved new image at ./dataset/ui/Navigation bars/wf_201_002.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 6 - 12.png
# Saved new image at ./dataset/ui/Navigation bars/1142_020.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 3 - 117.png
# Saved new image at ./dataset/ui/Navigation bars/1220_036.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 3 - 111.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 1 - 07.png
# Saved new image at ./dataset/ui/Navigation bars/1213_031.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 6 - 114.png
# Saved new image at ./dataset/ui/Navigation bars/1218_039.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 5 - 11.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 1 - 01.png
# Saved new image at ./dataset/ui/Navigation bars/wf_108_027.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 2 - 116.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 4 - 04.png
# Saved new image at ./dataset/ui/Navigation bars/45641_042.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 3 - 09.png
# Saved new image at ./dataset/ui/Navigation bars/16953_033.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 3 - 03.png
# Saved new image at ./dataset/ui/Navigation bars/1212_029.png
# Saved new image at ./dataset/ui/Navigation bars/10588_020.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar - 5 - 05.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 4 - 118.png
# Saved new image at ./dataset/ui/Navigation bars/wf_114_036.png
# Saved new image at ./dataset/ui/Navigation bars/12920_030.png
# Saved new image at ./dataset/ui/Navigation bars/1231_024.png
# Saved new image at ./dataset/ui/Navigation bars/Navigation bar-dark - 5 - 119.png
# Folder Buttons has more than 200 images. Please check the data.
# Folder Text Fields has more than 200 images. Please check the data.
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 4 - 04.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 5 - 13.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 1 - 25.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 2 - 26.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 4 - 20.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 2 - 10.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 7 - 15.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 6 - 22.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 3 - 19.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 7 - 07.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 1 - 01.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 5 - 29.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 8 - 24.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 8 - 08.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 6 - 30.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 7 - 23.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 3 - 03.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 2 - 02.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 6 - 06.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 3 - 27.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 4 - 28.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 8 - 32.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 6 - 14.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 8 - 16.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 5 - 05.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 4 - 12.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 5 - 21.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 3 - 11.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 7 - 31.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet - 1 - 09.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 2 - 18.png
# Saved new image at ./dataset/ui/Side sheets/Side Sheet-dark - 1 - 17.png
# Folder Radio buttons has more than 200 images. Please check the data.
# Folder .DS_Store does not exist in either the origin or screenshot path. Please check the data.
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker-dark [desktop] - 2 - 699.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker-dark - 3 - 687.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker - 1 - 01.png
# Saved new image at ./dataset/ui/Date picker/Input Date Picker - 1 - 07.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker [desktop] - 2 - 15.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker-dark [desktop] - 3 - 700.png
# Saved new image at ./dataset/ui/Date picker/Input Date Picker-dark - 2 - 692.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker-dark [desktop] - 1 - 698.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker [desktop] - 1 - 11.png
# Saved new image at ./dataset/ui/Date picker/Input Date Picker-dark - 1 - 691.png
# Saved new image at ./dataset/ui/Date picker/Input Date Picker - 1 - 09.png
# Saved new image at ./dataset/ui/Date picker/Input Date Picker-dark - 2 - 694.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker [desktop] - 1 - 14.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker - 2 - 02.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker - 3 - 03.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker-dark - 3 - 690.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker [desktop] - 2 - 12.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker-dark - 2 - 686.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker [desktop] - 3 - 13.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker-dark - 1 - 685.png
# Saved new image at ./dataset/ui/Date picker/Input Date Picker - 2 - 10.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker - 2 - 05.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker-dark [desktop] - 3 - 697.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker-dark [desktop] - 1 - 695.png
# Saved new image at ./dataset/ui/Date picker/Input Date Picker - 2 - 08.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker-dark [desktop] - 2 - 696.png
# Saved new image at ./dataset/ui/Date picker/Input Date Picker-dark - 1 - 693.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker-dark - 1 - 688.png
# Saved new image at ./dataset/ui/Date picker/Docked Input Date Picker [desktop] - 3 - 16.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker - 3 - 06.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker-dark - 2 - 689.png
# Saved new image at ./dataset/ui/Date picker/Modal Date Picker - 1 - 04.png
# Folder Carousel has more than 200 images. Please check the data.
# Folder Top app bars has more than 200 images. Please check the data.

# %%
# Draw the folder tree of the ui_path directory
print('UI structure:')
draw_folder_tree(ui_path)
# Out:
# UI structure:
# |- Bottom app bars/ (32 files)
# |- Bottom sheets/ (16 files)
# |- Cards/ (192 files)
# |- Checkboxes/ (182 files)
# |- Chips/ (200 files)
# |- Date picker/ (32 files)
# |- FABs/ (200 files)
# |- Menu/ (36 files)
# |- Menu List/ (200 files)
# |- Navigation bars/ (44 files)
# |- Navigation rails/ (24 files)
# |- Progress indicators/ (40 files)
# |- Search/ (128 files)
# |- Segmented buttons/ (64 files)
# |- Side sheets/ (32 files)
# |- Sliders/ (199 files)
# |- Tabs/ (69 files)
# |- Time picker/ (24 files)
# |- Tooltips/ (8 files)

# %% [markdown]
# ### 2-3. Converting to TensorFlow Dataset
#
# Finally, use the `image_dataset_from_directory` function in TensorFlow to convert the `ui_path` folder into a TensorFlow dataset. This converted dataset is used for model training.

# %%
def build_dataset(subset):
  return tf.keras.preprocessing.image_dataset_from_directory(
      ui_path,
      validation_split=.20,
      subset=subset,
      label_mode="categorical",
      # Seed needs to provided when using validation_split and shuffle = True.
      # A fixed seed is used so that the validation set is stable across runs.
      seed=123,
      image_size=IMAGE_SIZE,
      batch_size=1)

train_ds = build_dataset("training")
class_names = tuple(train_ds.class_names)
train_size = train_ds.cardinality().numpy()
train_ds = train_ds.unbatch().batch(BATCH_SIZE)
train_ds = train_ds.repeat()

normalization_layer = tf.keras.layers.Rescaling(1. / 255)
preprocessing_model = tf.keras.Sequential([normalization_layer])
do_data_augmentation = False #@param {type:"boolean"}
if do_data_augmentation:
  preprocessing_model.add(
      tf.keras.layers.RandomRotation(40))
  preprocessing_model.add(
      tf.keras.layers.RandomTranslation(0, 0.2))
  preprocessing_model.add(
      tf.keras.layers.RandomTranslation(0.2, 0))
  # Like the old tf.keras.preprocessing.image.ImageDataGenerator(),
  # image sizes are fixed when reading, and then a random zoom is applied.
  # If all training inputs are larger than image_size, one could also use
  # RandomCrop with a batch size of 1 and rebatch later.
  preprocessing_model.add(
      tf.keras.layers.RandomZoom(0.2, 0.2))
  preprocessing_model.add(
      tf.keras.layers.RandomFlip(mode="horizontal"))
train_ds = train_ds.map(lambda images, labels:
                        (preprocessing_model(images), labels))

val_ds = build_dataset("validation")
valid_size = val_ds.cardinality().numpy()
val_ds = val_ds.unbatch().batch(BATCH_SIZE)
val_ds = val_ds.map(lambda images, labels:
                    (normalization_layer(images), labels))
# Out:
# Found 1722 files belonging to 19 classes.
# Using 1378 files for training.
# Found 1722 files belonging to 19 classes.
# Using 344 files for validation.

# %% [markdown]
# ## 3. Training
#
# ### 3-1. Defining the model
#
# All it takes is to put a linear classifier on top of the feature_extractor_layer with the Hub module.
#
# For speed, we start out with a non-trainable feature_extractor_layer, but you can also enable fine-tuning for greater accuracy.

# %%
do_fine_tuning = False #@param {type:"boolean"}

# %%
print("Building model with", model_handle)
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=IMAGE_SIZE + (3,)),
    hub.KerasLayer(model_handle, trainable=do_fine_tuning),
    # tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(len(class_names),
                          kernel_regularizer=tf.keras.regularizers.l2(0.0001))
])
model.build((None,)+IMAGE_SIZE+(3,))
model.summary()
# Out:
# Building model with https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1792)              4363712
#
#  dense (Dense)               (None, 19)                34067
#
# =================================================================
# Total params: 4397779 (16.78 MB)
# Trainable params: 34067 (133.07 KB)
# Non-trainable params: 4363712 (16.65 MB)
# _________________________________________________________________

# %% [markdown]
# ### 3-2. Training the model

# %%
model.compile(
  optimizer=tf.keras.optimizers.legacy.SGD(learning_rate=0.005, momentum=0.9), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])

# %%
steps_per_epoch = train_size // BATCH_SIZE
validation_steps = valid_size // BATCH_SIZE
hist = model.fit(
    train_ds,
    epochs=10, 
    steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,
    validation_steps=validation_steps).history
# Out:
# Epoch 1/10
# 86/86 [==============================] - 7s 59ms/step - loss: 1.1877 - accuracy: 0.8154 - val_loss: 0.7889 - val_accuracy: 0.9524
# Epoch 2/10
# 86/86 [==============================] - 5s 54ms/step - loss: 0.7254 - accuracy: 0.9809 - val_loss: 0.7226 - val_accuracy: 0.9851
# Epoch 3/10
# 86/86 [==============================] - 4s 52ms/step - loss: 0.6832 - accuracy: 0.9905 - val_loss: 0.6941 - val_accuracy: 0.9911
# Epoch 4/10
# 86/86 [==============================] - 5s 53ms/step - loss: 0.6645 - accuracy: 0.9963 - val_loss: 0.6805 - val_accuracy: 0.9911
# Epoch 5/10
# 86/86 [==============================] - 4s 52ms/step - loss: 0.6536 - accuracy: 0.9971 - val_loss: 0.6692 - val_accuracy: 0.9911
# Epoch 6/10
# 86/86 [==============================] - 4s 52ms/step - loss: 0.6474 - accuracy: 0.9978 - val_loss: 0.6606 - val_accuracy: 0.9911
# Epoch 7/10
# 86/86 [==============================] - 4s 52ms/step - loss: 0.6413 - accuracy: 0.9978 - val_loss: 0.6533 - val_accuracy: 0.9940
# Epoch 8/10
# 86/86 [==============================] - 4s 52ms/step - loss: 0.6354 - accuracy: 0.9985 - val_loss: 0.6501 - val_accuracy: 0.9940
# Epoch 9/10
# 86/86 [==============================] - 5s 54ms/step - loss: 0.6318 - accuracy: 0.9985 - val_loss: 0.6469 - val_accuracy: 0.9970
# Epoch 10/10
# 86/86 [==============================] - 5s 57ms/step - loss: 0.6288 - accuracy: 0.9993 - val_loss: 0.6435 - val_accuracy: 0.9970

# %% [markdown]
# ### 3-3. Monitoring training progress

# %%
plt.figure()
plt.ylabel("Loss (training and validation)")
plt.xlabel("Training Steps")
plt.ylim([0,2])
plt.plot(hist["loss"])
plt.plot(hist["val_loss"])

plt.figure()
plt.ylabel("Accuracy (training and validation)")
plt.xlabel("Training Steps")
plt.ylim([0,1])
plt.plot(hist["accuracy"])
plt.plot(hist["val_accuracy"])

# %% [markdown]
# ### 3-4. Testing the custom trained model

# %%
x, y = next(iter(val_ds))
image = x[0, :, :, :]
true_index = np.argmax(y[0])
plt.imshow(image)
plt.axis('off')
plt.show()

# Expand the validation image to (1, 224, 224, 3) before predicting the label
prediction_scores = model.predict(np.expand_dims(image, axis=0))
predicted_index = np.argmax(prediction_scores)
print("True label: " + class_names[true_index])
print("Predicted label: " + class_names[predicted_index])
# Out:
# 1/1 [==============================] - 1s 602ms/step
# True label: Chips
# Predicted label: Chips

# %% [markdown]
# ## 4. Save and convert the model
#
# Finally, you can save the trained model to deploy it to TF Serving or TFJS as follows.
#
# ### 4-1. Saving the model

# %%
saved_model_path = f"{root_path}saved_model/{model_name}"
tf.saved_model.save(model, saved_model_path)
# Out:
# INFO:tensorflow:Assets written to: ./dataset/saved_model/mobilenet_v2_140_224/assets
# INFO:tensorflow:Assets written to: ./dataset/saved_model/mobilenet_v2_140_224/assets

# %% [markdown]
# ### 4-2 Convert Saved_model to TFJS
#
# Now that we have a trained model, we can convert it to TFJS format for use in the browser. We will use the `tensorflowjs_converter` to do this.

# %%
# set the path to the tfjs model
tfjs_model_path = f"{root_path}tfjs_model/{model_name}"

# convert the tf_saved_model to tfjs model via tensorflowjs_converter

# !tensorflowjs_converter --input_format=tf_saved_model {saved_model_path} {tfjs_model_path} --output_format=tfjs_graph_model

# %%
import os
import json

# Set the base URL
base_url = "https://m3.material.io/components"

# List all folders in ui_path
folder_names = [entry.name for entry in os.scandir(ui_path) if entry.is_dir()]

# Function to convert name to URL
def name_to_url(name):
    # Convert to lower case and replace spaces with hyphens
    url_name = name.lower().replace(" ", "-")
    # Construct the URL
    url = f"{base_url}/{url_name}"
    return url

# Generate labels list
labels = [{"name": name, "url": name_to_url(name), "id": i+1} for i, name in enumerate(sorted(folder_names))]

print(labels)

# Write to metadata.json under the tfjs_model_path
with open(os.path.join(tfjs_model_path, "metadata.json"), "w") as f:
    json.dump({"labels": labels}, f)
# Out:
# [{'name': 'Bottom app bars', 'url': 'https://m3.material.io/components/bottom-app-bars', 'id': 1}, {'name': 'Bottom sheets', 'url': 'https://m3.material.io/components/bottom-sheets', 'id': 2}, {'name': 'Cards', 'url': 'https://m3.material.io/components/cards', 'id': 3}, {'name': 'Checkboxes', 'url': 'https://m3.material.io/components/checkboxes', 'id': 4}, {'name': 'Chips', 'url': 'https://m3.material.io/components/chips', 'id': 5}, {'name': 'Date picker', 'url': 'https://m3.material.io/components/date-picker', 'id': 6}, {'name': 'FABs', 'url': 'https://m3.material.io/components/fabs', 'id': 7}, {'name': 'Menu', 'url': 'https://m3.material.io/components/menu', 'id': 8}, {'name': 'Menu List', 'url': 'https://m3.material.io/components/menu-list', 'id': 9}, {'name': 'Navigation bars', 'url': 'https://m3.material.io/components/navigation-bars', 'id': 10}, {'name': 'Navigation rails', 'url': 'https://m3.material.io/components/navigation-rails', 'id': 11}, {'name': 'Progress indicators', 'url': 'https://m3.material.io/components/progress-indicators', 'id': 12}, {'name': 'Search', 'url': 'https://m3.material.io/components/search', 'id': 13}, {'name': 'Segmented buttons', 'url': 'https://m3.material.io/components/segmented-buttons', 'id': 14}, {'name': 'Side sheets', 'url': 'https://m3.material.io/components/side-sheets', 'id': 15}, {'name': 'Sliders', 'url': 'https://m3.material.io/components/sliders', 'id': 16}, {'name': 'Tabs', 'url': 'https://m3.material.io/components/tabs', 'id': 17}, {'name': 'Time picker', 'url': 'https://m3.material.io/components/time-picker', 'id': 18}, {'name': 'Tooltips', 'url': 'https://m3.material.io/components/tooltips', 'id': 19}]
